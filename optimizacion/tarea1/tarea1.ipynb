# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def f1(x1,x2):
    return x1**2 - x2**2
def f2(x1,x2):
    return 2*x1*x2
x1 = np.linspace(-5,5,100)
x2 = np.linspace(-5,5,100)
X1,X2 = np.meshgrid(x1,x2)

Z1 = f1(X1,X2)
Z2 = f2(X1,X2)

plt.figure(figsize=(8, 6))
contour1 = plt.contour(X1, X2, Z1, levels=[12], colors='b', linewidths=2, label=r"$f_1(x_1, x_2) = 12$", zorder=1)
contour2 = plt.contour(X1, X2, Z2, levels=[16], colors='r', linewidths=2, label=r"$f_2(x_1, x_2) = 16$", zorder=1)
plt.clabel(contour1, inline=True, fontsize=10)
plt.clabel(contour2, inline=True, fontsize=10)

plt.scatter([4,-4],[2,-2], color='g', label=r"$(4,2)$ y $(-4,-2)$", zorder=2) # calculados analiticamente
plt.legend()
# Out:
# /tmp/ipykernel_5553/1094398044.py:13: UserWarning: The following kwargs were not used by contour: 'label'
#   contour1 = plt.contour(X1, X2, Z1, levels=[12], colors='b', linewidths=2, label=r"$f_1(x_1, x_2) = 12$", zorder=1)
# /tmp/ipykernel_5553/1094398044.py:14: UserWarning: The following kwargs were not used by contour: 'label'
#   contour2 = plt.contour(X1, X2, Z2, levels=[16], colors='r', linewidths=2, label=r"$f_2(x_1, x_2) = 16$", zorder=1)
