# %% [markdown]
# # Juan Carlos Perez Ramirez
# ## Procesamiento de Lenguaje Natural
# ## Practica 2: NLTK

# %%
import nltk
nltk.download()
from nltk.book import * # importa todos los textos
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
type(text1)
# Out:
# nltk.text.Text

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
text1.concordance("monstrous")
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %%
text1[:100]
# Out:
# ['[',
#  'Moby',
#  'Dick',
#  'by',
#  'Herman',
#  'Melville',
#  '1851',
#  ']',
#  'ETYMOLOGY',
#  '.',
#  '(',
#  'Supplied',
#  'by',
#  'a',
#  'Late',
#  'Consumptive',
#  'Usher',
#  'to',
#  'a',
#  'Grammar',
#  'School',
#  ')',
#  'The',
#  'pale',
#  'Usher',
#  '--',
#  'threadbare',
#  'in',
#  'coat',
#  ',',
#  'heart',
#  ',',
#  'body',
#  ',',
#  'and',
#  'brain',
#  ';',
#  'I',
#  'see',
#  'him',
#  'now',
#  '.',
#  'He',
#  'was',
#  'ever',
#  'dusting',
#  'his',
#  'old',
#  'lexicons',
#  'and',
#  'grammars',
#  ',',
#  'with',
#  'a',
#  'queer',
#  'handkerchief',
#  ',',
#  'mockingly',
#  'embellished',
#  'with',
#  'all',
#  'the',
#  'gay',
#  'flags',
#  'of',
#  'all',
#  'the',
#  'known',
#  'nations',
#  'of',
#  'the',
#  'world',
#  '.',
#  'He',
#  'loved',
#  'to',
#  'dust',
#  'his',
#  'old',
#  'grammars',
#  ';',
#  'it',
#  'somehow',
#  'mildly',
#  'reminded',
#  'him',
#  'of',
#  'his',
#  'mortality',
#  '.',
#  '"',
#  'While',
#  'you',
#  'take',
#  'in',
#  'hand',
#  'to',
#  'school',
#  'others',
#  ',']

# %%
text1.concordance?
# Out:
# Signature: text1.concordance(word, width=79, lines=25)
# Docstring:
# Prints a concordance for ``word`` with the specified context window.
# Word matching is not case-sensitive.
#
# :param word: The target word or phrase (a list of strings)
# :type word: str or list
# :param width: The width of each line, in characters (default=80)
# :type width: int
# :param lines: The number of lines to display (default=25)
# :type lines: int
#
# :seealso: ``ConcordanceIndex``
# File:      ~/.local/lib/python3.10/site-packages/nltk/text.py
# Type:      method

# %%
text6.concordance("direction")
# Out:
# Displaying 2 of 2 matches:
# ugh wiper ! I fart in your general direction ! You mother was a hamster and you
# ime , mac , unclog my nose in your direction ', sons of a window - dresser ! So

# %%
text1.similar("monstrous")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 text1.similar("monstrous")
#
# NameError: name 'text1' is not defined

# %%
text2.common_contexts(["monstrous", "very"])
# Out:
# am_glad a_pretty a_lucky is_pretty be_glad

# %%
text4.dispersion_plot(["citizens", "democracy", "freedom", "duties", "America"])

# %%
set(text3)
# Out:
# {'ones',
#  'circumcised',
#  'custom',
#  'cup',
#  'Happy',
#  'let',
#  'whatsoever',
#  'touching',
#  'hastened',
#  'hire',
#  'Jabbok',
#  'reach',
#  'dwelled',
#  'touch',
#  'Beno',
#  'talking',
#  'asses',
#  'surety',
#  'Kadmonites',
#  'seest',
#  'Iscah',
#  'pitcher',
#  'embalm',
#  'forward',
#  'kill',
#  'current',
#  'oa',
#  'service',
#  'peaceably',
#  'Rebekah',
#  'visit',
#  'bare',
#  'Leah',
#  'Swear',
#  'hil',
#  'mock',
#  'damsels',
#  'favoured',
#  'labour',
#  'Saul',
#  'Luz',
#  'weapons',
#  'eyed',
#  'oxen',
#  'mead',
#  'parts',
#  'Ephrath',
#  'gro',
#  'subdue',
#  'En',
#  'verified',
#  'round',
#  'took',
#  'bear',
#  'until',
#  'Accad',
#  'garment',
#  'portion',
#  'about',
#  'childr',
#  'Art',
#  'ourselves',
#  'bowed',
#  'Phallu',
#  'Return',
#  'selfwill',
#  'second',
#  'anoth',
#  'consent',
#  'side',
#  'sweet',
#  'it',
#  'pitch',
#  'bottle',
#  'kindled',
#  'continued',
#  'nourished',
#  'Zidon',
#  'sheepshearers',
#  'gifts',
#  'north',
#  'each',
#  'overthrew',
#  'lamp',
#  'yielded',
#  'Lud',
#  'eventide',
#  'Cainan',
#  'chariot',
#  'befall',
#  'sixty',
#  'grass',
#  'stones',
#  'Timna',
#  'despised',
#  'fail',
#  'Moreover',
#  'twelve',
#  'Heber',
#  'ungirded',
#  'lands',
#  'afterward',
#  'songs',
#  'Hamor',
#  'liveth',
#  'Keturah',
#  'strengthened',
#  'comforted',
#  'Gether',
#  'sowed',
#  'ours',
#  'Binding',
#  'Hittites',
#  'Mizraim',
#  'seven',
#  'households',
#  'chamber',
#  'you',
#  'Neither',
#  'certain',
#  'Aran',
#  'what',
#  'I',
#  'Cast',
#  'rams',
#  'seekest',
#  'sepulchres',
#  'removed',
#  'raise',
#  'fill',
#  'Adam',
#  'himself',
#  'lie',
#  'maidservants',
#  'bondwoman',
#  'possessions',
#  'Why',
#  'beginning',
#  'stole',
#  'tim',
#  'Jezer',
#  'yet',
#  'sister',
#  'almon',
#  'Hamathite',
#  'lovest',
#  'Eldaah',
#  'unto',
#  's',
#  'Dodanim',
#  'plagued',
#  'might',
#  'upon',
#  'yea',
#  'broken',
#  'Hanoch',
#  'hundredfo',
#  'Appoint',
#  'buy',
#  'oversig',
#  'Gilead',
#  'Haran',
#  'Me',
#  'storehouses',
#  'mayest',
#  'drink',
#  'stayed',
#  'Abide',
#  'grisl',
#  'Ishmael',
#  'dale',
#  'down',
#  'begat',
#  'order',
#  'Nahath',
#  'cut',
#  ')',
#  'Resen',
#  'lean',
#  'defiled',
#  'trembled',
#  'aw',
#  'worth',
#  'feebler',
#  'shepherd',
#  'forgotten',
#  'lesser',
#  'divineth',
#  'audience',
#  'midwife',
#  'alive',
#  'ash',
#  'hundredth',
#  'distressed',
#  'heel',
#  'carry',
#  'adder',
#  'reward',
#  'errand',
#  'two',
#  'given',
#  'some',
#  'Rosh',
#  'past',
#  'seem',
#  'years',
#  'if',
#  'cast',
#  'comest',
#  'wolf',
#  'Isui',
#  'they',
#  'meal',
#  'Wilt',
#  'clothes',
#  'bakemeats',
#  'obeisance',
#  'God',
#  'violently',
#  'goodly',
#  'food',
#  'Shalem',
#  'sac',
#  'tempt',
#  'hear',
#  'habitations',
#  'perish',
#  'over',
#  'northward',
#  'become',
#  'Eri',
#  'generations',
#  'tenth',
#  'lead',
#  'sad',
#  'vagabond',
#  'onyx',
#  'Ishbak',
#  'goeth',
#  'couching',
#  'heaven',
#  'messenger',
#  'Come',
#  'thin',
#  'ever',
#  'us',
#  'smooth',
#  'justice',
#  'drunken',
#  'for',
#  'Huz',
#  'fro',
#  'am',
#  'Perizzite',
#  'Lest',
#  'life',
#  'sewed',
#  'ki',
#  'Samlah',
#  'up',
#  'anger',
#  'sword',
#  'eaten',
#  'other',
#  'covered',
#  'getting',
#  'plenteousness',
#  'Bedad',
#  'heads',
#  'summer',
#  'his',
#  'restrained',
#  'ye',
#  'na',
#  'LORD',
#  'Zo',
#  'ford',
#  'seek',
#  'pleasant',
#  'branches',
#  'natio',
#  'abomination',
#  'likene',
#  'field',
#  'moveth',
#  'now',
#  'LO',
#  'Arphaxad',
#  'Erech',
#  'failed',
#  'trough',
#  'Hazezontamar',
#  'barr',
#  'wounding',
#  'blame',
#  'dreams',
#  'earing',
#  'thread',
#  'alo',
#  'lingered',
#  'prison',
#  'Arkite',
#  'wages',
#  'moon',
#  'rightly',
#  'drove',
#  'lentiles',
#  'Jobab',
#  'Dedan',
#  'firmament',
#  'number',
#  'Hittite',
#  'whomsoever',
#  'interpretations',
#  'Zibeon',
#  'compassed',
#  'requite',
#  'conspired',
#  'lion',
#  'Tubal',
#  'spe',
#  'hide',
#  'fell',
#  'peaceable',
#  'thee',
#  'and',
#  'Sodom',
#  'appe',
#  'yielding',
#  'Egyptians',
#  'answered',
#  'Onam',
#  'Bless',
#  'lad',
#  'scattered',
#  'such',
#  'Shimron',
#  'hence',
#  'fetcht',
#  'wash',
#  'Feed',
#  'worthy',
#  'fifth',
#  'Kedar',
#  'fallen',
#  'changed',
#  'thirteenth',
#  'widowhood',
#  'sixteen',
#  ',)',
#  'ride',
#  'meditate',
#  'protest',
#  'hindermost',
#  'Egyptia',
#  'in',
#  'spare',
#  'wicked',
#  'refrained',
#  'amongst',
#  'Belah',
#  'withhold',
#  'uppermost',
#  'Hinder',
#  'kingdom',
#  'vessels',
#  'guilty',
#  'week',
#  'Padan',
#  'behind',
#  'rouse',
#  'plagues',
#  'smote',
#  'Elparan',
#  'mountain',
#  'gard',
#  'Seth',
#  'putting',
#  'Hivite',
#  'appear',
#  'mourn',
#  'tak',
#  'fruit',
#  'tree',
#  'Lay',
#  'Thus',
#  'firstlings',
#  'awaked',
#  'loins',
#  'ri',
#  'lamentati',
#  'occupation',
#  'dungeon',
#  'guiding',
#  'Put',
#  'concerning',
#  'Slay',
#  'why',
#  'filled',
#  'divide',
#  'Kenites',
#  'enmity',
#  'ladder',
#  'Onan',
#  'breadth',
#  'sight',
#  'till',
#  'planted',
#  'garments',
#  'Cush',
#  'neck',
#  'end',
#  'persons',
#  'judgment',
#  'Emins',
#  'haven',
#  'Abram',
#  'nation',
#  'sou',
#  'doth',
#  'sinners',
#  'Ashbel',
#  'dreadful',
#  'spices',
#  'whence',
#  'curseth',
#  'breed',
#  'Zepho',
#  'treasure',
#  'judge',
#  'pottage',
#  'increased',
#  'myrrh',
#  'ships',
#  'Ashteroth',
#  'brick',
#  'Ohad',
#  'Akan',
#  'Perizzit',
#  'leaves',
#  'were',
#  'foolishly',
#  'laws',
#  'baker',
#  'Let',
#  'doer',
#  'grace',
#  'plenty',
#  'did',
#  'fruits',
#  'Wherefore',
#  'things',
#  'wo',
#  'prosperous',
#  'travailed',
#  'assembly',
#  'fir',
#  'desolate',
#  'chief',
#  'force',
#  'restore',
#  'worshipped',
#  'To',
#  'It',
#  'communing',
#  'fifteen',
#  'possessor',
#  'Surely',
#  'confound',
#  'break',
#  'roll',
#  'devoured',
#  'Simeon',
#  'vowedst',
#  'consume',
#  'rich',
#  'His',
#  'Mash',
#  'tender',
#  'afterwards',
#  'messengers',
#  ',',
#  'willing',
#  'Joktan',
#  'angry',
#  'whosoever',
#  'Cause',
#  'horses',
#  'harm',
#  'burdens',
#  'spies',
#  'fly',
#  'stead',
#  'aga',
#  'physicians',
#  'leaped',
#  'mouths',
#  'erected',
#  'deceitfully',
#  'cry',
#  'charge',
#  'Pinon',
#  'pigeon',
#  'themselv',
#  'Chezib',
#  'withered',
#  'Hereby',
#  'aprons',
#  'smell',
#  'named',
#  'of',
#  'nati',
#  'should',
#  'Gera',
#  'witness',
#  'cleave',
#  'overtook',
#  'favour',
#  'Ask',
#  'deliver',
#  'Elon',
#  'Zohar',
#  'Zemarite',
#  'prevailed',
#  'abide',
#  'morning',
#  'grieved',
#  'shoelatchet',
#  'Ur',
#  'Arioch',
#  'whoredom',
#  'Jared',
#  'lamb',
#  'bow',
#  'knowest',
#  'belly',
#  'dowry',
#  'cloud',
#  'falsely',
#  'befell',
#  'Babel',
#  'Benjamin',
#  'handmaids',
#  'marvelled',
#  'prospered',
#  'Es',
#  'shamed',
#  "'",
#  'than',
#  'host',
#  'cursed',
#  'fruitful',
#  'giants',
#  'rose',
#  'thirty',
#  'Be',
#  'Gentiles',
#  'reproa',
#  'played',
#  'toward',
#  'thousands',
#  'whether',
#  'dress',
#  'bade',
#  'fashion',
#  'Are',
#  'sinew',
#  'redeemed',
#  'Esek',
#  'accepted',
#  'Drink',
#  'Joseph',
#  'butlers',
#  'air',
#  'comi',
#  'beyond',
#  'numbered',
#  'Hushim',
#  'Naphtuhim',
#  'prevail',
#  'according',
#  'mouth',
#  'Anamim',
#  'womenservan',
#  'nostrils',
#  'activity',
#  'marry',
#  'Gaza',
#  'Of',
#  'book',
#  'moving',
#  'beget',
#  'cakes',
#  'firstborn',
#  'Bilhah',
#  'officers',
#  'Asshur',
#  'We',
#  'folly',
#  'Ham',
#  'Sidon',
#  'deprived',
#  'Hobah',
#  'conceived',
#  'daughers',
#  'images',
#  'Teman',
#  'utmost',
#  'subtil',
#  'chesnut',
#  'speckled',
#  'know',
#  'blameless',
#  'Timnah',
#  'pilgrimage',
#  'observed',
#  'twenty',
#  'ask',
#  'shut',
#  'can',
#  'woman',
#  'Reu',
#  'Ard',
#  'repented',
#  'chode',
#  'taken',
#  'least',
#  'Milcah',
#  'fire',
#  'Sered',
#  'vail',
#  'Rameses',
#  'direct',
#  'together',
#  'repenteth',
#  'While',
#  'afflict',
#  'cunning',
#  'clothed',
#  'Shinab',
#  'bulls',
#  'men',
#  'Whereas',
#  'Abelmizraim',
#  'commandments',
#  'Hemam',
#  'fatness',
#  'For',
#  'elder',
#  'seventh',
#  'floc',
#  'most',
#  'prey',
#  'strove',
#  'Escape',
#  'word',
#  'likeness',
#  'bones',
#  'wherewith',
#  'cities',
#  'horsemen',
#  'form',
#  'five',
#  'Jehovahjireh',
#  'flo',
#  'mist',
#  'reigned',
#  'uncircumcised',
#  'thi',
#  'lawgiver',
#  'make',
#  'sorely',
#  'tabret',
#  'Goshen',
#  'wept',
#  'bitter',
#  'openly',
#  'touched',
#  'kids',
#  'where',
#  'Lie',
#  'Levi',
#  'sons',
#  'steal',
#  'waxed',
#  'Spake',
#  'olive',
#  'ewes',
#  'door',
#  'died',
#  'Bring',
#  'offer',
#  'always',
#  'Dinhabah',
#  'Serug',
#  'kn',
#  'clo',
#  'morter',
#  'Eber',
#  'butler',
#  'needeth',
#  'thoroughly',
#  'reign',
#  'judged',
#  'wat',
#  'sadly',
#  'thyself',
#  'from',
#  'concubines',
#  'bands',
#  'laughed',
#  'speak',
#  'charged',
#  'Alvan',
#  'overdrive',
#  'fellow',
#  'sit',
#  'me',
#  'possession',
#  'cannot',
#  'Woman',
#  'Hebron',
#  'windows',
#  'Maachah',
#  'both',
#  'obtain',
#  'accept',
#  'preserved',
#  'Javan',
#  'refused',
#  'poor',
#  'Isra',
#  'fo',
#  'seen',
#  'Thorns',
#  'plant',
#  'provide',
#  'Pathrusim',
#  'bondmen',
#  'possessi',
#  'wind',
#  'wilt',
#  'Ezbon',
#  'lifted',
#  'lodge',
#  'tribute',
#  'excellency',
#  'silv',
#  'd',
#  'fa',
#  'Set',
#  'still',
#  'wotteth',
#  'country',
#  'spee',
#  'lighted',
#  'ascending',
#  'deferred',
#  'floor',
#  'lieth',
#  'Ziphion',
#  'Give',
#  'organ',
#  'walking',
#  'found',
#  'thus',
#  'leave',
#  'decreased',
#  'commended',
#  'words',
#  'wentest',
#  'Whence',
#  'Aram',
#  'Philistines',
#  'poverty',
#  'morever',
#  'coffin',
#  'ruler',
#  'whereof',
#  'require',
#  'ring',
#  'sworn',
#  'prosper',
#  'names',
#  'Enmishpat',
#  'tar',
#  'caused',
#  'grievous',
#  'sh',
#  'mi',
#  'Reuben',
#  'interpret',
#  'laugh',
#  'worse',
#  'except',
#  'numbering',
#  'roof',
#  'nakedness',
#  'th',
#  'Areli',
#  'Bethuel',
#  'deceiver',
#  'give',
#  'Shur',
#  'Mahalath',
#  'Which',
#  'Damascus',
#  'nourish',
#  'sacks',
#  'bundles',
#  'If',
#  'poured',
#  'six',
#  'deeds',
#  'fountains',
#  'Chesed',
#  'bound',
#  'mischief',
#  'wander',
#  'among',
#  'when',
#  'beheld',
#  'wombs',
#  'sackcloth',
#  'dipped',
#  'castles',
#  'Yet',
#  'back',
#  'hurt',
#  'beside',
#  'discreet',
#  'met',
#  'priests',
#  'herself',
#  'Girgasite',
#  'speedily',
#  'Jordan',
#  'sixth',
#  'sheep',
#  'slept',
#  'bough',
#  'dead',
#  'fury',
#  'manner',
#  'wall',
#  'sojourner',
#  'gave',
#  'her',
#  'Melchizedek',
#  'Gather',
#  'Massa',
#  'driven',
#  'gre',
#  'grove',
#  'fowls',
#  'receive',
#  'overtake',
#  'heart',
#  'fled',
#  'Judah',
#  'rebuked',
#  'dine',
#  'chariots',
#  'Er',
#  'stolen',
#  'balm',
#  'Amraphel',
#  'delight',
#  'Haste',
#  'Aner',
#  'Ararat',
#  'kindred',
#  'Our',
#  'golden',
#  'foreskin',
#  'knoweth',
#  'abroad',
#  'springing',
#  'Amalek',
#  'departed',
#  'y',
#  'wickedness',
#  'nothing',
#  'Calah',
#  'counted',
#  'speaking',
#  'Caphtorim',
#  'bak',
#  'slay',
#  'sought',
#  'ill',
#  'hou',
#  'exchange',
#  'stuff',
#  'freely',
#  'seventy',
#  'herdmen',
#  'spake',
#  'beast',
#  'ten',
#  'delivered',
#  'spotted',
#  'Mizz',
#  'Gershon',
#  'ram',
#  'curse',
#  'Dothan',
#  'prepared',
#  'provision',
#  'flaming',
#  'seeth',
#  'magicians',
#  'birds',
#  'Naaman',
#  'lien',
#  'lords',
#  'health',
#  'joint',
#  'strakes',
#  'voice',
#  'stranger',
#  'evening',
#  'neither',
#  'Abraham',
#  'iniquity',
#  'grisled',
#  'Arbah',
#  'received',
#  'intreat',
#  'Judith',
#  'speaketh',
#  'enemies',
#  'Ephron',
#  'run',
#  'Gatam',
#  'either',
#  'conceal',
#  'Kenaz',
#  'shore',
#  'shear',
#  'heir',
#  'Hear',
#  'My',
#  'commanded',
#  'tents',
#  'toucheth',
#  'pray',
#  'nations',
#  'Admah',
#  'salt',
#  'corn',
#  'cubits',
#  'Kittim',
#  'Ethiopia',
#  'destitute',
#  'presence',
#  'Kedemah',
#  'handfuls',
#  'void',
#  'barren',
#  'wrestlings',
#  'rid',
#  'fish',
#  'walked',
#  'coming',
#  'meanest',
#  'none',
#  'Salah',
#  'lives',
#  'Jebusites',
#  'chi',
#  'going',
#  'next',
#  'womb',
#  'certainly',
#  'perform',
#  'Magog',
#  'gopher',
#  'sacrifice',
#  'without',
#  'half',
#  'Galeed',
#  'dim',
#  'said',
#  'Bered',
#  'reached',
#  'With',
#  'deed',
#  'brethren',
#  'shaved',
#  'Hori',
#  'Husham',
#  'ashamed',
#  'imagined',
#  'Leummim',
#  'far',
#  'towns',
#  'so',
#  'threshingfloor',
#  'hither',
#  ...}
