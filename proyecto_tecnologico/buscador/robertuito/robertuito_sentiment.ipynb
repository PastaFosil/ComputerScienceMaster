# %%
from pysentimiento import create_analyzer
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re
import os
import matplotlib.gridspec as gridspec
import json

# %%
analyzer = create_analyzer(task="sentiment", lang="es")

# %%
Nombre_Archivo = f"../resultados/res_unicos_corrupcion.json"

with open(Nombre_Archivo, "r") as file:
    all_hrefs = json.load(file)

# %%
all_hrefs
# Out:
# ['https://es.wikipedia.org/wiki/Ley',
#  'https://www.unir.net/revista/derecho/que-es-corrupcion/#:~:text=Etimol%C3%B3gicamente%2C%20el%20vocablo%20corrupci%C3%B3n%20proviene,al%20sistema%20social%20o%20a%20las',
#  'https://es.wikipedia.org/wiki/Corrupci%C3%B3n_pol%C3%ADtica',
#  'https://www.interpol.int/es/Delitos/Corrupcion',
#  'https://dle.rae.es/corrupci%C3%B3n',
#  'https://www.unodc.org/newsletter/es/200601/page004.html',
#  'https://www.argentina.gob.ar/servicio/denunciar-un-hecho-de-corrupcion',
#  'https://www.fiscales.gob.ar/corrupcion/',
#  'https://www.un.org/es/observances/anti-corruption-day',
#  'https://www.argentina.gob.ar/sites/default/files/nuevos_enfoques_sobre_la_corrupcion_perspectiva_historica_federal_y_multidimensional_0.pdf',
#  'https://www.youtube.com/watch?v=UaaagN5Umsw',
#  'http://servicios.infoleg.gob.ar/infolegInternet/anexos/40000-44999/41466/norma.htm',
#  'https://www.cij.gov.ar/causas-de-corrupcion.html',
#  'https://www.oas.org/es/temas/corrupcion.asp',
#  'https://denuncias.anticorrupcion.gob.ar/tipo_denuncia.php?id=1',
#  'https://www.youtube.com/watch?v=Be3q1GSMhf8',
#  'http://servicios.infoleg.gob.ar/infolegInternet/anexos/115000-119999/116954/norma.htm',
#  'https://www.clarin.com/politica/escandalo-corrupcion-vtv-ministro-kicillof-entrego-empresario-militante-negocio-20-millones-dolares_0_oqpzUjP62k.html?srsltid=AfmBOoqvlkdjtTcXUvaeAGeQo4onY2wjQIGzl9DHLCeNXEVltNJ9gUyx',
#  'http://www.oas.org/es/sla/dlc/mesicic/',
#  'https://www.youtube.com/watch?v=43JFioRQy3s',
#  'https://www.mpf.gob.ar/pia/files/2022/07/PIA-informe-trata-y-corrupcion-1.pdf',
#  'http://ve.scielo.org/scielo.php?script=sci_arttext&pid=S1315-99842005000100004',
#  'https://www.santafe.gob.ar/noticias/noticia/281887/',
#  'https://www.caf.com/es/blog/4-formas-de-reducir-la-corrupcion-en-america-latina/',
#  'https://www.scielo.org.ar/scielo.php?script=sci_arttext&pid=S2314-30612017000200012',
#  'https://www.legislatura.gob.ar/posts/dia-internacional-de-la-lucha-contra-la-corrupcion3531.html',
#  'https://causasdecorrupcion.org/',
#  'http://buenosaires.gob.ar/legalytecnica/oficina-de-integridad-publica/delitos-de-corrupcion',
#  'https://www.ohchr.org/es/good-governance/corruption-and-human-rights',
#  'https://www.lanacion.com.ar/opinion/ficha-limpia-entre-la-hipocresia-y-una-sociedad-sobreadaptada-a-la-corrupcion-nid06122024/',
#  'http://bibliotecadigital.econ.uba.ar/download/cya/cya_v9_n17_01.pdf',
#  'https://nuso.org/articulo/desmitificar-la-corrupcion/',
#  'https://repositorio.uca.edu.ar/handle/123456789/13698',
#  'https://dpej.rae.es/lema/corrupci%C3%B3n',
#  'https://archivos.juridicas.unam.mx/www/bjv/libros/14/6677/8.pdf',
#  'https://www.clarin.com/tema/corrupcion.html?srsltid=AfmBOooMCctzVEMEN6s1mfT4hCNDU-0U2PlbhttbEqx1w2AJFaDPsMUw',
#  'https://www.memoria.fahce.unlp.edu.ar/art_revistas/pr.2828/pr.2828.pdf',
#  'https://www.coe.int/es/web/portal/-/anti-corruption-day-states-must-take-determined-action-to-protect-democracy-against-corruption-',
#  'https://www.lanacion.com.ar/tema/corrupcion-en-la-argentina-tid49367/',
#  'https://elpais.com/noticias/corrupcion/',
#  'https://acij.org.ar/argentina-y-la-lucha-contra-la-corrupcion-un-desafio-inaplazable/',
#  'https://polhis.com.ar/index.php/polhis/article/view/376/479',
#  'https://www.mpf.gob.ar/pia/la-procuraduria-de-investigaciones-administrativas-destaca-una-serie-de-acciones-realizadas-durante-2024-y-senala-la-importancia-de-la-cooperacion-nacional-e-internacional/',
#  'https://publications.iadb.org/publications/spanish/document/Corrupci%C3%B3n-normal-y-corrupci%C3%B3n-sist%C3%A9mica.pdf',
#  'https://www.instagram.com/compromisojudicial/reel/DDXrhJWvbYw/',
#  'http://buenosaires.gob.ar/tramites/denuncias-de-actos-de-corrupcion-del-personal-de-la-administracion-publica',
#  'https://definicion.de/corrupcion/',
#  'https://ethicsunwrapped.utexas.edu/glossary/corrupcion?lang=es',
#  'https://repositorio.uca.edu.ar/bitstream/123456789/13698/1/corrupci%C3%B3n-instituciones-publicas.pdf',
#  'https://cnc.gob.gt/',
#  'https://www.bbc.com/mundo/topics/c404v5z55rrt',
#  'https://www.un.org/es/desa/el-25-del-gasto-publico-mundial-se-pierde-en-corrupcion',
#  'https://www.unodc.org/e4j/es/anti-corruption/module-1/key-issues/corruption---baseline-definition.html',
#  'https://www.caf.com/es/especiales/corrupcion-cero/',
#  'https://poderciudadano.org/indice-de-percepcion-de-la-corrupcion-2023-sin-esfuerzos-significativos-y-sin-lugar-en-la-agenda-actual-argentina-continua-estancada/',
#  'http://www.scielo.org.mx/scielo.php?script=sci_arttext&pid=S2448-51362023000200265',
#  'https://www.youtube.com/watch?v=ZEF7hV7spDk',
#  'https://www.economicas.uba.ar/investigacion/wp-content/uploads/docin_ciap_v4_n3.pdf',
#  'https://datosmacro.expansion.com/estado/indice-percepcion-corrupcion',
#  'https://www.transparency.org/es/press/cpi2023-corruption-perceptions-index-weakening-justice-systems-leave-corruption-unchecked',
#  'https://www.unir.net/revista/derecho/que-es-corrupcion/',
#  'https://www.infobae.com/tag/corrupcion/',
#  'https://capacitacion.inap.gob.ar/actividad/etica-transparencia-e-integridad-en-el-estado-perspectivas-y-herramientas-de-lucha-contra-la-corrupcion-2/',
#  'https://www.flacsoandes.edu.ec/web/imagesFTP/1275931953.raimundo_soto.pdf',
#  'https://blogs.worldbank.org/es/voices/la-corrupcion-ha-evolucionado-y-lo-mismo-deberia-suceder-con-las-iniciativas-para-combatirla',

#  'https://datosmacro.expansion.com/estado/indice-percepcion-corrupcion/argentina',
#  'https://www.redalyc.org/journal/5519/551971848008/html/',
#  'https://www.eldiarioar.com/sociedad/dia-internacional-corrupcion-celebra-9-diciembre_1_11885100.html',
#  'https://shs.cairn.info/revue-internationale-de-droit-penal-2003-1-page-577?lang=fr',
#  'https://revistas.usc.gal/index.php/epc/article/view/9415/13202',
#  'https://elpais.com/noticias/corrupcion-politica/',
#  'https://journal.paho.org/es/articulos/corrupcion-su-relacion-con-prevalencia-mortalidad-por-enfermedades-no-transmisibles-sus',
#  'https://www.interpol.int/es/Delitos/Corrupcion/Corrupcion-en-el-deporte',
#  'https://www.bcb.gob.bo/webdocs/transparenciadocs/CARTILLA%20BCB%20FINAL%20WEB.pdf',
#  'https://www.planificacion.gob.bo/uploads/normativa/A_DS214_123ESP.pdf',
#  'https://www.procuraduria.gob.bo/paginacontenido/500',
#  'https://www.planificacion.gob.bo/uploads/normativa/convencion_interamericana_contra_corrupcion.pdf',
#  'https://www.oas.org/juridico/spanish/mesicic3_repdom_normas.pdf',
#  'http://www.scielo.org.bo/scielo.php?script=sci_arttext&pid=S2070-81572011000200019',
#  'https://www2.congreso.gob.pe/sicr/cendocbib/con4_uibd.nsf/3496ADACB0EE54FF05257E0E00741B97/$FILE/06_La_corrupcion.pdf',
#  'https://www.youtube.com/watch?v=bTYw11yBCCk',
#  'https://www2.congreso.gob.pe/sicr/cendocbib/con4_uibd.nsf/D1D7AA08E451BA0205257DFF00703587/$FILE/III-M.Rowland-Vision.pdf',
#  'https://tsj.bo/transparencia/',
#  'https://ciudadesintermedias.org.bo/wp-content/uploads/2024/06/006-Vania-Sandoval-y-Rubens-Barbery-Corrupcion-y-Desarrollo.pdf',
#  'http://www.scielo.org.bo/scielo.php?script=sci_arttext&pid=S2518-44312022000200069',
#  'https://www.antifrau.cat/sites/default/files/Documents/Recursos/0002esp_eines_integricat.pdf',
#  'https://www.pj.gov.py/images/contenido/daii/cisni/unidad2/undos51.htm',
#  'https://www.aduana.gob.bo/aduana7/content/unidad-de-lucha-contra-la-corrupci%C3%B3n-0',
#  'https://accesoalajusticia.org/glossary/corrupcion/',
#  'https://www.jacobea.edu.mx/revista/numeros/numero14/1.Javier-Miranzo-Di%CC%81az-Causas-Efectos-Corrupcion-Sociedades-Democraticas.pdf',
#  'https://www.lisainstitute.com/blogs/blog/causas-consecuencias-corrupcion-privada?srsltid=AfmBOophswaQnQ5EiN3M8Yk8cKDntobZtnDMslffngTEi-Gm6CFPdnax',
#  'https://archivos.juridicas.unam.mx/www/bjv/libros/11/5244/4.pdf',
#  'https://transparenciacolombia.org.co/reflexiones-sobre-las-causas-de-la-corrupcion-y-los-medios-para-enfrentarla/',
#  'https://clad.org/wp-content/uploads/2022/04/Webinar2-Presentacion-MVilloria.pdf',
#  'https://financialcrimeacademy.org/es/soborno-y-corrupcion-definicion-y-proceso-2/',
#  'http://www.scielo.org.mx/scielo.php?script=sci_arttext&pid=S2448-49112019000200013',
#  'https://www.gob.mx/cms/uploads/attachment/file/727371/LIbro-cuento_10_CLAVES_Final_web.pdf',
#  'https://www.opengovpartnership.org/es/actions-for-strong-anti-corruption-efforts/',
#  'https://www.argentina.gob.ar/sites/default/files/pereyra_final.pdf',
#  'https://justicia.gob.bo/cms/files/Cuaderno2.pdf',
#  'https://www.imf.org/es/Blogs/Articles/2019/04/04/blog-fm-ch2-tackling-corruption-in-government',
#  'https://www.redalyc.org/journal/267/26770144005/',
#  'https://blog.up.edu.mx/topic/posgrados-de-gobierno-y-economia/cuales-son-los-principales-tipos-de-corrupcion',
#  'https://revistaseug.ugr.es/index.php/acfs/article/download/538/628/',
#  'https://www.estudiosanticorrupcion.org/que-es-la-corrupcion/',
#  'https://ibero.mx/iberoforum/1/pdf/resendiz1lugar.pdf',
#  'http://www.scielo.org.pe/scielo.php?script=sci_arttext&pid=S2219-71682023000100072',
#  'https://transparenciacolombia.org.co/que-es-corrupcion-alac/',
#  'https://dialnet.unirioja.es/descarga/articulo/174814.pdf',
#  'https://www.redalyc.org/journal/2911/291157943001/html/',
#  'https://www.mpfn.gob.pe/fiscalias_anticorrupcion/prevencion/',
#  'https://gestionyestrategia.azc.uam.mx/index.php/rge/article/view/734/1277',
#  'https://anticorrupcionmx.org/historico/archivo/biblioteca/FactSheet_4.pdf',
#  'https://www.iberdrola.com/gobierno-corporativo/sistema-gobernanza-sostenibilidad/politicas-gobierno-corporativo/politica-contra-corrupcion-fraude',
#  'https://blog.up.edu.mx/posgrados-de-gobierno-y-economia/10-temas-de-investigacion-sobre-la-corrupcion',
#  'https://www.contraloria.gob.bo/inicio/consejo-nacional-de-lucha-contra-la-corrupcion/',
#  'https://ojs.ministeriopublico.gov.py/index.php/rjmp/article/download/90/113/1415',
#  'http://www.chile.gob.cl/chile/blog/ocde/la-corrupcion-tiene-el-potencial-de-obstaculizar-el-crecimiento-y-el',
#  'https://www.undp.org/es/latin-america/blog/la-formula-contra-la-corrupcion',
#  'https://journals.openedition.org/ccec/5949',
#  'https://blogs.iadb.org/administracion-publica/es/la-corrupcion-no-tiene-que-ser-una-cotidianidad/',
#  'https://www.bancomundial.org/es/events/2023/04/13/anticorruption-for-development-ac4d-global-partnership',
#  'https://www.imf.org/external/pubs/ft/fandd/spa/2000/06/pdf/klitgaar.pdf',
#  'https://www1.funcionpublica.gov.co/web/eva/curso-integridad',
#  'https://www.scielo.cl/scielo.php?script=sci_arttext&pid=S0718-33992018000100104',
#  'https://www.eda.admin.ch/deza/es/home/temas-cosude/reformas-estado-economia/corrupcion.html',
#  'https://library.fes.de/pdf-files/bueros/fesamcentral/07607.pdf',
#  'https://www.dw.com/es/corrupci%C3%B3n/t-38371376',
#  'https://www.iese.edu/es/insight/articulos/etica-negocio-causas-corrupcion-empresa/',
#  'https://www.justice.gov/es/objetivo-42-combatir-la-corrupcion-los-delitos-financieros-y-el-fraude',
#  'https://alertadores.funcionpublica.gob.mx/',
#  'https://www.icd.go.cr/portalicd/images/docs/upp/estado_derecho/CulturaLegalidad_Lec10.pdf',
#  'https://es.wikipedia.org/wiki/Corrupci%C3%B3n_(abuso_de_poder)',
#  'http://www.fiscaliadechile.cl/Fiscalia/areas/corrupcion.jsp',
#  'https://www.ciperchile.cl/2024/04/14/corrupcion-dentro-del-estado-y-redes-de-poder/',
#  'https://www.chiletransparente.cl/wp-content/files_mf/1607614519radiografiadelacorrupcion.pdf',
#  'https://www.bcn.cl/portal/leyfacil/recurso/prevencion-deteccion-y-persecucion-de-la-corrupcion',
#  'https://portal.paco.gov.co/',
#  'https://www.mindeporte.gov.co/mindeporte/quienes-somos/dependencias/oficina-control-interno-disciplinario/denuncias-actos-corrupcion',
#  'https://revistas.unimilitar.edu.co/index.php/dere/article/view/3667/3866',
#  'https://www.urf.gov.co/webcenter/ShowProperty?nodeId=%2FConexionContent%2FWCC_CLUSTER-107073%2F%2FidcPrimaryFile&revision=latestreleased',
#  'https://www.itrc.gov.co/observatorio/',
#  'https://www.wola.org/es/programa/seguridad-ciudadana/luchando-contra-la-corrupcion-y-exponiendo-la-impunidad/',
#  'https://www.infobae.com/colombia/2024/12/07/petro-solicito-a-fiscalia-investigar-a-los-hermanos-de-santos-y-pastrana-por-multimillonario-escandalo-de-corrupcion-en-coosalud/',
#  'https://efe.com/mundo/2024-05-09/el-escandalo-de-corrupcion-crece-en-colombia/',
#  'https://ministeriopublico.poder-judicial.go.cr/index.php/servicios-a-la-ciudadania/inspeccion-fiscal',
#  'https://www.mjp.go.cr/Cohecho/Cohecho',
#  'https://www.pgr.go.cr/servicios/procuraduria-de-la-etica-publica-pep/material-de-interes-para-la-prevencion-de-la-corrupcion/documentos-para-la-prevencion-de-la-corrupcion-en-la-funcion-publica/',
#  'http://www.pgrweb.go.cr/scij/Busqueda/Normativa/Normas/nrm_texto_completo.aspx?nValor1=1&nValor2=53738',
#  'https://pjenlinea3.poder-judicial.go.cr/biblioteca/uploads/Archivos/Articulo/la%20corrupcion%20como%20una%20violacion.pdf',
#  'http://observatorioplanificacion.cepal.org/es/marcos-regulatorios/ley-8422-contra-la-corrupcion-y-el-enriquecimiento-ilicito-en-la-funcion',
#  'https://www.iidh.ed.cr/images/Publicaciones/GestionesInstitu/Corrupcion%20y%20derechos%20economicos%20y%20sociales%20en%20America%20Latina%20Ecuador%20Mexico%20y%20Republica%20Dominicana%20%20.pdf',
#  'http://www.pgrweb.go.cr/scij/Busqueda/Normativa/Normas/nrm_texto_completo.aspx?param1=NRTC&nValor1=1&nValor2=53738&nValor3=90841&strTipM=TC',
#  'https://www.unodc.org/ropan/es/corrupcin.html',
#  'https://www.abogados.or.cr/indice-de-percepcion-de-la-corrupcion-2023-deja-en-mala-posicion-a-costa-rica/',
#  'https://formacion.tirant.com/cr/corrupcion-claves-y-estrategias-para-combatirla/',
#  'https://www.pgr.go.cr/publicaciones/nueva-ley-contra-la-corrupcion-y-el-enriquecimiento-ilicito-en-la-funcion-publica-anotada-y-comentada/',
#  'https://cicap.ucr.ac.cr/la-corrupcion-sigue-permeando-en-costa-rica/',
#  'https://www.ucr.ac.cr/medios/documentos/2006/corrupcion.pdf',
#  'https://delfino.cr/2024/02/la-corrupcion-un-asunto-de-realidad-o-de-percepcion',
#  'https://www.presidencia.go.cr/noticias/pcd-desarticula-presunta-estructura-de-corrupcion-interna-en-moin',
#  'https://blogs.worldbank.org/es/voices/controlar-la-corrupcion-no-es-opcional',
#  'http://www.scielo.org.mx/scielo.php?script=sci_arttext&pid=S0188-25032016000100119',
#  'https://www.elsevier.es/es-revista-contaduria-administracion-87-articulo-corrupcion-como-proceso-organizacional-comprendiendo-S0186104216300407',
#  'https://www.redalyc.org/pdf/686/68601005.pdf',
#  'https://cgrfiles.cgr.go.cr/publico/docsweb/documentos/leyes-reglamentos/ley-contra-corrupcion-anotada-concordada.pdf',
#  'https://cdsa.aacademica.org/000-066/732.pdf',
#  'https://www2.deloitte.com/content/dam/Deloitte/mx/Documents/finance/Honestidad_vs_Corrupcion-2016.pdf',
#  'https://www.revistasmarcialpons.es/revistaayer/article/view/la-nueva-historia-de-la-corrupcion-slgunas-reflexiones-sobre-la-/1231',
#  'https://www.tse.go.cr/pdf/normativa/reglamentoleycontracorrupcion.pdf',
#  'https://nuso.org/articulo/guatemala-la-corrupcion-como-crisis-de-gobierno/',
#  'https://e-archivo.uc3m.es/bitstreams/bee3f85b-fe27-4303-b444-122db4ab2445/download',
#  'https://www.icccostarica.com/images/Anticorrupcion/ICC_Clausula_Anticorrupcion.pdf',
#  'https://pactoglobal.org.mx/la-corrupcion-no-se-combate-solo-se-controla-eduardo-bohorquez/',
#  'https://www.manosunidas.org/observatorio/hambre-mundo/corrupcion-causa-hambre',
#  'https://dialnet.unirioja.es/descarga/articulo/6622338.pdf',
#  'https://www.ifac.org/knowledge-gateway/discussion/por-que-es-indispensable-romper-el-circulo-vicioso-de-la-corrupcion-aunque-sea-dificil',
#  'http://www.cubadebate.cu/etiqueta/corrupcion/',
#  'https://treaties.un.org/doc/source/recenttexts/corruption_s.pdf',
#  'https://weareallin.iom.int/es/fraude-corrupcion-y-utilizacion-indebida-de-los-recursos',
#  'https://www.granma.cu/cuba/2024-02-25/el-descontrol-genera-ilegalidades-y-corrupcion-25-02-2024-21-02-07',
#  'https://datosmacro.expansion.com/estado/indice-percepcion-corrupcion/cuba',
#  'https://www.youtube.com/watch?v=BhXkPPuDbYI',
#  'https://www.unilim.fr/trahs/2547',
#  'https://e-revistas.uc3m.es/index.php/EUNOM/article/view/2175',
#  'https://action4justice.org/legal_areas/corrupcion/como-puedo-probar-la-corrupcion/?lang=es',
#  'https://idehpucp.pucp.edu.pe/boletin-eventos/anotas-acerca-del-concepto-de-corrupcion-25559/',
#  'https://publications.iadb.org/es/publicacion/13577/metodologia-para-el-diagnostico-prevencion-y-control-de-la-corrupcion-en',
#  'https://contralacorrupcion.mx/',
#  'https://clad.org/2023/04/14/autor-oscar-bernalette/entendiendo-la-corrupcion/',
#  'https://www2.deloitte.com/mx/es/pages/dnoticias/articles/asi-se-mide-corrupcion-mexico.html',
#  'https://revistasonline.inap.es/index.php/GAPP/article/view/269/269',
#  'http://www.anticorruptionday.org/documents/actagainstcorruption/print/materials2016/corr16_fs_DEVELOPMENT_es_PRINT.pdf',
#  'https://www.unodc.org/peruandecuador/es/02AREAS/corrupcion.html',
#  'https://www.vanderbilt.edu/lapop/news/011520-Ecuador-primicias.pdf',
#  'https://www.cpccs.gob.ec/wp-content/uploads/2016/02/Actos-corrupcion.pdf',
#  'https://www.finanzas.gob.ec/denuncia-aqui-la-corrupcion/',
#  'https://www.cpccs.gob.ec/transparencia-y-lucha-contra-la-corrupcion/introduccion/',
#  'https://www.ucm.es/data/cont/media/www/pag-10588/2015_06_not11.pdf',
#  'https://www.elmundo.es/andalucia/2024/12/09/6756e11a21efa0d1258b4575.html']

# %%
directorio = "../all_pages_clean"
archivos = os.listdir(directorio)
print(len(archivos))
# Out:
# 551

# %%
paginas_dict = {i: url for i, url in enumerate(all_hrefs)}

sentiments = ["NEG", "NEU", "POS"]

# %%
texts = {}
errors = []
for f in archivos:
    try:
        with open(os.path.join(directorio, f), 'r', encoding='utf-8') as file:
            texts[f] = file.read()
    except:
        print(f"Error reading file {f}")
        errors.append(f)

# %%
results = {}
for f in texts:
    pred = analyzer.predict(texts[f])
    probas_redondeadas = {k: round(v, 2) for k, v in pred.probas.items()}
    results[int(f[:4])] = probas_redondeadas
    print(f)
    print(pred.output, probas_redondeadas)
    print("\n\n")
# Out:
# 0012.txt
# NEG {'NEG': 0.84, 'NEU': 0.14, 'POS': 0.01}
#
#
#
# 0571.txt
# NEU {'NEG': 0.09, 'NEU': 0.86, 'POS': 0.05}
#
#
#
# 0200.txt
# NEU {'NEG': 0.07, 'NEU': 0.81, 'POS': 0.12}
#
#
#
# 0394.txt
# NEU {'NEG': 0.07, 'NEU': 0.79, 'POS': 0.15}
#
#
#
# 0397.txt
# NEG {'NEG': 0.65, 'NEU': 0.32, 'POS': 0.03}
#
#
#
# 0199.txt
# POS {'NEG': 0.11, 'NEU': 0.43, 'POS': 0.45}
#
#
#
# 0004.txt
# NEU {'NEG': 0.25, 'NEU': 0.68, 'POS': 0.08}
#
#
#
# 0002.txt
# NEU {'NEG': 0.33, 'NEU': 0.64, 'POS': 0.03}
#
#
#
# 0420.txt
# NEU {'NEG': 0.22, 'NEU': 0.6, 'POS': 0.19}
#
#
#
# 0587.txt
# NEU {'NEG': 0.43, 'NEU': 0.55, 'POS': 0.02}
#
#
#
# 0238.txt
# NEU {'NEG': 0.06, 'NEU': 0.85, 'POS': 0.09}
#
#
#
# 0246.txt
# NEU {'NEG': 0.07, 'NEU': 0.74, 'POS': 0.19}
#
#
#
# 0324.txt
# NEU {'NEG': 0.23, 'NEU': 0.62, 'POS': 0.16}
#
#
#
# 0444.txt
# NEU {'NEG': 0.1, 'NEU': 0.79, 'POS': 0.1}
#
#
#
# 0059.txt
# NEG {'NEG': 0.63, 'NEU': 0.33, 'POS': 0.04}
#
#
#
# 0489.txt
# NEU {'NEG': 0.24, 'NEU': 0.7, 'POS': 0.06}
#
#
#
# 0487.txt
# NEU {'NEG': 0.18, 'NEU': 0.78, 'POS': 0.05}
#
#
#
# 0019.txt
# NEU {'NEG': 0.07, 'NEU': 0.85, 'POS': 0.09}
#
#
#
# 0105.txt
# NEU {'NEG': 0.23, 'NEU': 0.69, 'POS': 0.08}
#
#
#
# 0525.txt
# NEG {'NEG': 0.61, 'NEU': 0.34, 'POS': 0.05}
#
#
#
# 0159.txt
# NEU {'NEG': 0.24, 'NEU': 0.73, 'POS': 0.03}
#
#
#
# 0245.txt
# NEU {'NEG': 0.08, 'NEU': 0.87, 'POS': 0.06}
#
#
#
# 0526.txt
# NEU {'NEG': 0.13, 'NEU': 0.8, 'POS': 0.07}
#
#
#
# 0484.txt
# NEG {'NEG': 0.66, 'NEU': 0.32, 'POS': 0.01}
#
#
#
# 0406.txt
# NEU {'NEG': 0.07, 'NEU': 0.79, 'POS': 0.15}
#
#
#
# 0275.txt
# NEU {'NEG': 0.26, 'NEU': 0.71, 'POS': 0.03}
#
#
#
# 0127.txt
# NEU {'NEG': 0.19, 'NEU': 0.65, 'POS': 0.15}
#
#
#
# 0263.txt
# NEU {'NEG': 0.03, 'NEU': 0.63, 'POS': 0.34}
#
#
#
# 0187.txt
# NEU {'NEG': 0.22, 'NEU': 0.68, 'POS': 0.1}
#
#
#
# 0431.txt
# NEU {'NEG': 0.23, 'NEU': 0.72, 'POS': 0.05}
#
#
#
# 0128.txt
# NEU {'NEG': 0.19, 'NEU': 0.75, 'POS': 0.06}
#
#
#
# 0217.txt
# NEU {'NEG': 0.17, 'NEU': 0.66, 'POS': 0.17}
#
#
#
# 0379.txt
# NEU {'NEG': 0.25, 'NEU': 0.68, 'POS': 0.07}
#
#
#
# 0249.txt
# POS {'NEG': 0.21, 'NEU': 0.29, 'POS': 0.5}
#
#
#
# 0099.txt
# NEG {'NEG': 0.57, 'NEU': 0.4, 'POS': 0.03}
#
#
#
# 0045.txt
# NEU {'NEG': 0.09, 'NEU': 0.88, 'POS': 0.04}
#
#
#
# 0216.txt
# NEU {'NEG': 0.07, 'NEU': 0.69, 'POS': 0.25}
#
#
#
# 0198.txt
# NEU {'NEG': 0.06, 'NEU': 0.74, 'POS': 0.21}
#
#
#
# 0522.txt
# NEU {'NEG': 0.25, 'NEU': 0.64, 'POS': 0.1}
#
#
#
# 0345.txt
# NEU {'NEG': 0.13, 'NEU': 0.6, 'POS': 0.27}
#
#
#
# 0277.txt
# NEU {'NEG': 0.09, 'NEU': 0.81, 'POS': 0.1}
#
#
#
# 0040.txt
# NEU {'NEG': 0.14, 'NEU': 0.71, 'POS': 0.15}
#
#
#
# 0556.txt
# NEU {'NEG': 0.24, 'NEU': 0.7, 'POS': 0.06}
#
#
#
# 0276.txt
# NEU {'NEG': 0.12, 'NEU': 0.83, 'POS': 0.05}
#
#
#
# 0572.txt
# NEU {'NEG': 0.11, 'NEU': 0.73, 'POS': 0.16}
#
#
#
# 0115.txt
# NEU {'NEG': 0.07, 'NEU': 0.86, 'POS': 0.07}
#
#
#
# 0478.txt
# NEU {'NEG': 0.09, 'NEU': 0.64, 'POS': 0.27}
#
#
#
# 0154.txt
# NEU {'NEG': 0.31, 'NEU': 0.64, 'POS': 0.04}
#
#
#
# 0125.txt
# NEG {'NEG': 0.51, 'NEU': 0.45, 'POS': 0.04}
#
#
#
# 0471.txt
# NEU {'NEG': 0.29, 'NEU': 0.66, 'POS': 0.05}
#
#
#
# 0430.txt
# NEU {'NEG': 0.07, 'NEU': 0.78, 'POS': 0.15}
#
#
#
# 0121.txt
# NEU {'NEG': 0.18, 'NEU': 0.73, 'POS': 0.1}
#
#
#
# 0329.txt
# NEU {'NEG': 0.32, 'NEU': 0.64, 'POS': 0.05}
#
#
#
# 0013.txt
# NEU {'NEG': 0.07, 'NEU': 0.82, 'POS': 0.11}
#
#
#
# 0256.txt
# NEU {'NEG': 0.05, 'NEU': 0.8, 'POS': 0.15}
#
#
#
# 0131.txt
# NEU {'NEG': 0.3, 'NEU': 0.67, 'POS': 0.04}
#
#
#
# 0117.txt
# NEU {'NEG': 0.24, 'NEU': 0.7, 'POS': 0.06}
#
#
#
# 0359.txt
# NEG {'NEG': 0.67, 'NEU': 0.3, 'POS': 0.03}
#
#
#
# 0057.txt
# NEU {'NEG': 0.09, 'NEU': 0.79, 'POS': 0.12}
#
#
#
# 0332.txt
# NEU {'NEG': 0.09, 'NEU': 0.77, 'POS': 0.14}
#
#
#
# 0391.txt
# NEU {'NEG': 0.19, 'NEU': 0.74, 'POS': 0.07}
#
#
#
# 0590.txt
# NEU {'NEG': 0.29, 'NEU': 0.63, 'POS': 0.08}
#
#
#
# 0155.txt
# NEU {'NEG': 0.26, 'NEU': 0.67, 'POS': 0.07}
#
#
#
# 0166.txt
# NEU {'NEG': 0.25, 'NEU': 0.7, 'POS': 0.05}
#
#
#
# 0168.txt
# NEU {'NEG': 0.36, 'NEU': 0.55, 'POS': 0.09}
#
#
#
# 0044.txt
# NEU {'NEG': 0.16, 'NEU': 0.64, 'POS': 0.2}
#
#
#
# 0343.txt
# NEU {'NEG': 0.16, 'NEU': 0.71, 'POS': 0.13}
#
#
#
# 0223.txt
# NEG {'NEG': 0.51, 'NEU': 0.47, 'POS': 0.02}
#
#
#
# 0535.txt
# NEU {'NEG': 0.15, 'NEU': 0.8, 'POS': 0.05}
#
#
#
# 0094.txt
# NEU {'NEG': 0.05, 'NEU': 0.79, 'POS': 0.16}
#
#
#
# 0301.txt
# NEU {'NEG': 0.11, 'NEU': 0.74, 'POS': 0.16}
#
#
#
# 0293.txt
# NEU {'NEG': 0.16, 'NEU': 0.74, 'POS': 0.11}
#
#
#
# 0029.txt
# NEU {'NEG': 0.26, 'NEU': 0.7, 'POS': 0.04}
#
#
#
# 0523.txt
# NEU {'NEG': 0.1, 'NEU': 0.73, 'POS': 0.17}
#
#
#
# 0466.txt
# NEU {'NEG': 0.1, 'NEU': 0.71, 'POS': 0.19}
#
#
#
# 0591.txt
# NEU {'NEG': 0.11, 'NEU': 0.8, 'POS': 0.09}
#
#
#
# 0558.txt
# NEG {'NEG': 0.87, 'NEU': 0.12, 'POS': 0.02}
#
#
#
# 0106.txt
# NEU {'NEG': 0.37, 'NEU': 0.58, 'POS': 0.05}
#
#
#
# 0143.txt
# NEU {'NEG': 0.32, 'NEU': 0.62, 'POS': 0.06}
#
#
#
# 0362.txt
# NEG {'NEG': 0.7, 'NEU': 0.27, 'POS': 0.03}
#
#
#
# 0555.txt
# NEU {'NEG': 0.11, 'NEU': 0.83, 'POS': 0.06}
#
#
#
# 0344.txt
# NEU {'NEG': 0.39, 'NEU': 0.58, 'POS': 0.03}
#
#
#
# 0076.txt
# NEU {'NEG': 0.25, 'NEU': 0.68, 'POS': 0.07}
#
#
#
# 0075.txt
# NEU {'NEG': 0.12, 'NEU': 0.78, 'POS': 0.1}
#
#
#
# 0174.txt
# NEU {'NEG': 0.23, 'NEU': 0.73, 'POS': 0.04}
#
#
#
# 0448.txt
# NEU {'NEG': 0.03, 'NEU': 0.87, 'POS': 0.09}
#
#
#
# 0534.txt
# NEU {'NEG': 0.09, 'NEU': 0.77, 'POS': 0.14}
#
#
#
# 0279.txt
# NEU {'NEG': 0.1, 'NEU': 0.78, 'POS': 0.12}
#
#
#
# 0214.txt
# NEG {'NEG': 0.84, 'NEU': 0.15, 'POS': 0.01}
#
#
#
# 0067.txt
# NEU {'NEG': 0.2, 'NEU': 0.7, 'POS': 0.11}
#
#
#
# 0551.txt
# NEU {'NEG': 0.1, 'NEU': 0.71, 'POS': 0.19}
#
#
#
# 0258.txt
# NEU {'NEG': 0.07, 'NEU': 0.84, 'POS': 0.09}
#
#
#
# 0084.txt
# NEU {'NEG': 0.21, 'NEU': 0.72, 'POS': 0.08}
#
#
#
# 0396.txt
# NEG {'NEG': 0.86, 'NEU': 0.13, 'POS': 0.01}
#
#
#
# 0014.txt
# NEG {'NEG': 0.65, 'NEU': 0.33, 'POS': 0.02}
#
#
#
# 0304.txt
# NEU {'NEG': 0.48, 'NEU': 0.49, 'POS': 0.03}
#
#
#
# 0145.txt
# NEU {'NEG': 0.35, 'NEU': 0.58, 'POS': 0.06}
#
#
#
# 0409.txt
# NEU {'NEG': 0.1, 'NEU': 0.79, 'POS': 0.1}
#
#
#
# 0203.txt
# NEU {'NEG': 0.25, 'NEU': 0.68, 'POS': 0.06}
#
#
#
# 0541.txt
# NEU {'NEG': 0.04, 'NEU': 0.65, 'POS': 0.31}
#
#
#
# 0190.txt
# NEU {'NEG': 0.11, 'NEU': 0.84, 'POS': 0.05}
#
#
#
# 0284.txt
# NEU {'NEG': 0.08, 'NEU': 0.84, 'POS': 0.07}
#
#
#
# 0533.txt
# NEU {'NEG': 0.1, 'NEU': 0.78, 'POS': 0.12}
#
#
#
# 0552.txt
# NEU {'NEG': 0.19, 'NEU': 0.74, 'POS': 0.07}
#
#
#
# 0034.txt
# NEU {'NEG': 0.2, 'NEU': 0.74, 'POS': 0.06}
#
#
#
# 0592.txt
# NEG {'NEG': 0.76, 'NEU': 0.21, 'POS': 0.03}
#
#
#
# 0438.txt
# NEU {'NEG': 0.36, 'NEU': 0.45, 'POS': 0.19}
#
#
#
# 0082.txt
# NEU {'NEG': 0.04, 'NEU': 0.61, 'POS': 0.34}
#
#
#
# 0282.txt
# NEG {'NEG': 0.88, 'NEU': 0.1, 'POS': 0.01}
#
#
#
# 0498.txt
# NEG {'NEG': 0.8, 'NEU': 0.19, 'POS': 0.01}
#
#
#
# 0261.txt
# NEU {'NEG': 0.08, 'NEU': 0.8, 'POS': 0.12}
#
#
#
# 0218.txt
# NEU {'NEG': 0.13, 'NEU': 0.81, 'POS': 0.06}
#
#
#
# 0298.txt
# NEU {'NEG': 0.13, 'NEU': 0.72, 'POS': 0.15}
#
#
#
# 0310.txt
# NEU {'NEG': 0.07, 'NEU': 0.85, 'POS': 0.08}
#
#
#
# 0206.txt
# NEU {'NEG': 0.09, 'NEU': 0.81, 'POS': 0.09}
#
#
#
# 0020.txt
# NEU {'NEG': 0.15, 'NEU': 0.7, 'POS': 0.14}
#
#
#
# 0536.txt
# NEU {'NEG': 0.15, 'NEU': 0.48, 'POS': 0.37}
#
#
#
# 0485.txt
# NEU {'NEG': 0.11, 'NEU': 0.82, 'POS': 0.08}
#
#
#
# 0388.txt
# NEU {'NEG': 0.06, 'NEU': 0.87, 'POS': 0.07}
#
#
#
# 0429.txt
# NEU {'NEG': 0.34, 'NEU': 0.59, 'POS': 0.07}
#
#
#
# 0510.txt
# NEG {'NEG': 0.51, 'NEU': 0.41, 'POS': 0.08}
#
#
#
# 0185.txt
# NEU {'NEG': 0.09, 'NEU': 0.54, 'POS': 0.38}
#
#
#
# 0569.txt
# NEU {'NEG': 0.13, 'NEU': 0.79, 'POS': 0.07}
#
#
#
# 0499.txt
# NEG {'NEG': 0.95, 'NEU': 0.05, 'POS': 0.01}
#
#
#
# 0092.txt
# NEU {'NEG': 0.17, 'NEU': 0.75, 'POS': 0.07}
#
#
#
# 0302.txt
# NEG {'NEG': 0.91, 'NEU': 0.08, 'POS': 0.01}
#
#
#
# 0465.txt
# NEU {'NEG': 0.12, 'NEU': 0.78, 'POS': 0.1}
#
#
#
# 0011.txt
# NEU {'NEG': 0.12, 'NEU': 0.71, 'POS': 0.17}
#
#
#
# 0141.txt
# NEU {'NEG': 0.07, 'NEU': 0.82, 'POS': 0.11}
#
#
#
# 0546.txt
# NEU {'NEG': 0.17, 'NEU': 0.76, 'POS': 0.08}
#
#
#
# 0172.txt
# NEU {'NEG': 0.13, 'NEU': 0.75, 'POS': 0.12}
#
#
#
# 0221.txt
# NEU {'NEG': 0.03, 'NEU': 0.66, 'POS': 0.31}
#
#
#
# 0331.txt
# NEG {'NEG': 0.79, 'NEU': 0.19, 'POS': 0.02}
#
#
#
# 0242.txt
# NEG {'NEG': 0.71, 'NEU': 0.26, 'POS': 0.03}
#
#
#
# 0557.txt
# NEU {'NEG': 0.07, 'NEU': 0.82, 'POS': 0.11}
#
#
#
# 0515.txt
# NEU {'NEG': 0.07, 'NEU': 0.78, 'POS': 0.16}
#
#
#
# 0085.txt
# NEU {'NEG': 0.08, 'NEU': 0.81, 'POS': 0.12}
#
#
#
# 0330.txt
# NEU {'NEG': 0.21, 'NEU': 0.54, 'POS': 0.25}
#
#
#
# 0550.txt
# NEU {'NEG': 0.05, 'NEU': 0.74, 'POS': 0.21}
#
#
#
# 0319.txt
# NEU {'NEG': 0.41, 'NEU': 0.51, 'POS': 0.08}
#
#
#
# 0538.txt
# NEU {'NEG': 0.13, 'NEU': 0.65, 'POS': 0.21}
#
#
#
# 0561.txt
# NEG {'NEG': 0.78, 'NEU': 0.19, 'POS': 0.03}
#
#
#
# 0080.txt
# NEU {'NEG': 0.36, 'NEU': 0.59, 'POS': 0.05}
#
#
#
# 0005.txt
# NEG {'NEG': 0.98, 'NEU': 0.02, 'POS': 0.0}
#
#
#
# 0586.txt
# NEU {'NEG': 0.06, 'NEU': 0.85, 'POS': 0.09}
#
#
#
# 0234.txt
# NEU {'NEG': 0.37, 'NEU': 0.59, 'POS': 0.03}
#
#
#
# 0339.txt
# NEU {'NEG': 0.02, 'NEU': 0.72, 'POS': 0.26}
#
#
#
# 0408.txt
# NEU {'NEG': 0.13, 'NEU': 0.53, 'POS': 0.34}
#
#
#
# 0577.txt
# NEU {'NEG': 0.12, 'NEU': 0.72, 'POS': 0.15}
#
#
#
# 0483.txt
# NEU {'NEG': 0.19, 'NEU': 0.74, 'POS': 0.07}
#
#
#
# 0368.txt
# NEU {'NEG': 0.38, 'NEU': 0.47, 'POS': 0.15}
#
#
#
# 0476.txt
# NEU {'NEG': 0.08, 'NEU': 0.73, 'POS': 0.19}
#
#
#
# 0150.txt
# NEU {'NEG': 0.05, 'NEU': 0.84, 'POS': 0.11}
#
#
#
# 0537.txt
# NEU {'NEG': 0.05, 'NEU': 0.84, 'POS': 0.11}
#
#
#
# 0229.txt
# NEG {'NEG': 0.49, 'NEU': 0.47, 'POS': 0.04}
#
#
#
# 0365.txt
# NEU {'NEG': 0.05, 'NEU': 0.85, 'POS': 0.1}
#
#
#
# 0110.txt
# NEG {'NEG': 0.56, 'NEU': 0.41, 'POS': 0.03}
#
#
#
# 0562.txt
# NEU {'NEG': 0.19, 'NEU': 0.74, 'POS': 0.07}
#
#
#
# 0007.txt
# NEU {'NEG': 0.26, 'NEU': 0.69, 'POS': 0.05}
#
#
#
# 0402.txt
# NEG {'NEG': 0.86, 'NEU': 0.12, 'POS': 0.02}
#
#
#
# 0180.txt
# NEU {'NEG': 0.25, 'NEU': 0.7, 'POS': 0.06}
#
#
#
# 0270.txt
# NEU {'NEG': 0.08, 'NEU': 0.81, 'POS': 0.11}
#
#
#
# 0416.txt
# NEG {'NEG': 0.67, 'NEU': 0.27, 'POS': 0.06}
#
#
#
# 0107.txt
# NEU {'NEG': 0.04, 'NEU': 0.71, 'POS': 0.25}
#
#
#
# 0357.txt
# NEU {'NEG': 0.05, 'NEU': 0.66, 'POS': 0.29}
#
#
#
# 0049.txt
# NEU {'NEG': 0.05, 'NEU': 0.79, 'POS': 0.16}
#
#
#
# 0513.txt
# NEU {'NEG': 0.34, 'NEU': 0.62, 'POS': 0.04}
#
#
#
# 0165.txt
# NEU {'NEG': 0.11, 'NEU': 0.67, 'POS': 0.21}
#
#
#
# 0140.txt
# NEU {'NEG': 0.04, 'NEU': 0.83, 'POS': 0.13}
#
#
#
# 0384.txt
# NEU {'NEG': 0.2, 'NEU': 0.73, 'POS': 0.08}
#
#
#
# 0123.txt
# NEU {'NEG': 0.42, 'NEU': 0.46, 'POS': 0.11}
#
#
#
# 0053.txt
# NEU {'NEG': 0.04, 'NEU': 0.82, 'POS': 0.14}
#
#
#
# 0454.txt
# NEU {'NEG': 0.03, 'NEU': 0.59, 'POS': 0.37}
#
#
#
# 0055.txt
# NEU {'NEG': 0.12, 'NEU': 0.75, 'POS': 0.13}
#
#
#
# 0352.txt
# NEU {'NEG': 0.1, 'NEU': 0.86, 'POS': 0.04}
#
#
#
# 0369.txt
# NEU {'NEG': 0.4, 'NEU': 0.55, 'POS': 0.05}
#
#
#
# 0083.txt
# NEU {'NEG': 0.19, 'NEU': 0.78, 'POS': 0.03}
#
#
#
# 0079.txt
# NEU {'NEG': 0.1, 'NEU': 0.5, 'POS': 0.4}
#
#
#
# 0381.txt
# NEU {'NEG': 0.03, 'NEU': 0.59, 'POS': 0.38}
#
#
#
# 0305.txt
# NEU {'NEG': 0.19, 'NEU': 0.74, 'POS': 0.07}
#
#
#
# 0458.txt
# NEG {'NEG': 0.92, 'NEU': 0.07, 'POS': 0.01}
#
#
#
# 0389.txt
# NEU {'NEG': 0.06, 'NEU': 0.79, 'POS': 0.14}
#
#
#
# 0299.txt
# NEG {'NEG': 0.92, 'NEU': 0.08, 'POS': 0.01}
#
#
#
# 0139.txt
# NEG {'NEG': 0.63, 'NEU': 0.28, 'POS': 0.1}
#
#
#
# 0488.txt
# NEU {'NEG': 0.08, 'NEU': 0.74, 'POS': 0.18}
#
#
#
# 0506.txt
# NEG {'NEG': 0.77, 'NEU': 0.22, 'POS': 0.02}
#
#
#
# 0064.txt
# NEU {'NEG': 0.23, 'NEU': 0.68, 'POS': 0.09}
#
#
#
# 0196.txt
# NEU {'NEG': 0.21, 'NEU': 0.72, 'POS': 0.07}
#
#
#
# 0317.txt
# NEU {'NEG': 0.09, 'NEU': 0.7, 'POS': 0.21}
#
#
#
# 0093.txt
# NEG {'NEG': 0.65, 'NEU': 0.31, 'POS': 0.04}
#
#
#
# 0269.txt
# NEG {'NEG': 0.91, 'NEU': 0.08, 'POS': 0.01}
#
#
#
# 0470.txt
# NEU {'NEG': 0.11, 'NEU': 0.83, 'POS': 0.06}
#
#
#
# 0164.txt
# NEU {'NEG': 0.13, 'NEU': 0.68, 'POS': 0.19}
#
#
#
# 0025.txt
# NEU {'NEG': 0.08, 'NEU': 0.8, 'POS': 0.13}
#
#
#
# 0380.txt
# NEU {'NEG': 0.24, 'NEU': 0.72, 'POS': 0.04}
#
#
#
# 0393.txt
# NEU {'NEG': 0.24, 'NEU': 0.7, 'POS': 0.06}
#
#
#
# 0063.txt
# NEG {'NEG': 0.68, 'NEU': 0.3, 'POS': 0.02}
#
#
#
# 0017.txt
# NEU {'NEG': 0.35, 'NEU': 0.61, 'POS': 0.04}
#
#
#
# 0191.txt
# NEG {'NEG': 0.67, 'NEU': 0.32, 'POS': 0.02}
#
#
#
# 0232.txt
# NEG {'NEG': 0.86, 'NEU': 0.11, 'POS': 0.03}
#
#
#
# 0016.txt
# NEU {'NEG': 0.11, 'NEU': 0.79, 'POS': 0.11}
#
#
#
# 0423.txt
# NEG {'NEG': 0.84, 'NEU': 0.15, 'POS': 0.01}
#
#
#
# 0048.txt
# NEG {'NEG': 0.9, 'NEU': 0.09, 'POS': 0.01}
#
#
#
# 0564.txt
# NEU {'NEG': 0.09, 'NEU': 0.86, 'POS': 0.05}
#
#
#
# 0445.txt
# NEU {'NEG': 0.18, 'NEU': 0.75, 'POS': 0.07}
#
#
#
# 0340.txt
# NEU {'NEG': 0.12, 'NEU': 0.74, 'POS': 0.14}
#
#
#
# 0531.txt
# NEU {'NEG': 0.24, 'NEU': 0.7, 'POS': 0.06}
#
#
#
# 0312.txt
# NEU {'NEG': 0.44, 'NEU': 0.46, 'POS': 0.1}
#
#
#
# 0026.txt
# NEU {'NEG': 0.07, 'NEU': 0.85, 'POS': 0.08}
#
#
#
# 0473.txt
# POS {'NEG': 0.21, 'NEU': 0.29, 'POS': 0.5}
#
#
#
# 0582.txt
# NEU {'NEG': 0.25, 'NEU': 0.63, 'POS': 0.13}
#
#
#
# 0356.txt
# NEU {'NEG': 0.14, 'NEU': 0.82, 'POS': 0.04}
#
#
#
# 0181.txt
# NEG {'NEG': 0.52, 'NEU': 0.41, 'POS': 0.07}
#
#
#
# 0101.txt
# NEU {'NEG': 0.16, 'NEU': 0.51, 'POS': 0.33}
#
#
#
# 0087.txt
# NEG {'NEG': 0.95, 'NEU': 0.05, 'POS': 0.0}
#
#
#
# 0148.txt
# NEU {'NEG': 0.11, 'NEU': 0.82, 'POS': 0.07}
#
#
#
# 0271.txt
# NEU {'NEG': 0.09, 'NEU': 0.83, 'POS': 0.07}
#
#
#
# 0333.txt
# NEU {'NEG': 0.06, 'NEU': 0.75, 'POS': 0.19}
#
#
#
# 0052.txt
# NEU {'NEG': 0.15, 'NEU': 0.66, 'POS': 0.19}
#
#
#
# 0171.txt
# NEU {'NEG': 0.4, 'NEU': 0.57, 'POS': 0.02}
#
#
#
# 0086.txt
# NEU {'NEG': 0.08, 'NEU': 0.76, 'POS': 0.16}
#
#
#
# 0441.txt
# NEU {'NEG': 0.22, 'NEU': 0.66, 'POS': 0.12}
#
#
#
# 0401.txt
# NEU {'NEG': 0.17, 'NEU': 0.7, 'POS': 0.13}
#
#
#
# 0024.txt
# NEU {'NEG': 0.13, 'NEU': 0.81, 'POS': 0.07}
#
#
#
# 0132.txt
# NEG {'NEG': 0.36, 'NEU': 0.34, 'POS': 0.3}
#
#
#
# 0547.txt
# NEU {'NEG': 0.1, 'NEU': 0.84, 'POS': 0.06}
#
#
#
# 0504.txt
# NEU {'NEG': 0.28, 'NEU': 0.68, 'POS': 0.05}
#
#
#
# 0281.txt
# NEG {'NEG': 0.59, 'NEU': 0.38, 'POS': 0.02}
#
#
#
# 0511.txt
# NEU {'NEG': 0.26, 'NEU': 0.71, 'POS': 0.03}
#
#
#
# 0274.txt
# NEU {'NEG': 0.12, 'NEU': 0.76, 'POS': 0.12}
#
#
#
# 0222.txt
# NEU {'NEG': 0.16, 'NEU': 0.77, 'POS': 0.07}
#
#
#
# 0204.txt
# NEU {'NEG': 0.09, 'NEU': 0.85, 'POS': 0.06}
#
#
#
# 0351.txt
# NEU {'NEG': 0.06, 'NEU': 0.88, 'POS': 0.06}
#
#
#
# 0228.txt
# NEU {'NEG': 0.18, 'NEU': 0.71, 'POS': 0.11}
#
#
#
# 0549.txt
# NEG {'NEG': 0.76, 'NEU': 0.22, 'POS': 0.03}
#
#
#
# 0192.txt
# NEG {'NEG': 0.52, 'NEU': 0.42, 'POS': 0.07}
#
#
#
# 0051.txt
# NEU {'NEG': 0.3, 'NEU': 0.64, 'POS': 0.06}
#
#
#
# 0038.txt
# NEU {'NEG': 0.09, 'NEU': 0.85, 'POS': 0.05}
#
#
#
# 0167.txt
# NEU {'NEG': 0.13, 'NEU': 0.81, 'POS': 0.06}
#
#
#
# 0303.txt
# NEG {'NEG': 0.86, 'NEU': 0.14, 'POS': 0.01}
#
#
#
# 0091.txt
# NEU {'NEG': 0.05, 'NEU': 0.57, 'POS': 0.38}
#
#
#
# 0516.txt
# NEU {'NEG': 0.06, 'NEU': 0.83, 'POS': 0.11}
#
#
#
# 0372.txt
# NEU {'NEG': 0.11, 'NEU': 0.81, 'POS': 0.07}
#
#
#
# 0568.txt
# NEU {'NEG': 0.15, 'NEU': 0.76, 'POS': 0.09}
#
#
#
# 0280.txt
# NEU {'NEG': 0.14, 'NEU': 0.79, 'POS': 0.07}
#
#
#
# 0097.txt
# NEU {'NEG': 0.17, 'NEU': 0.78, 'POS': 0.05}
#
#
#
# 0163.txt
# NEU {'NEG': 0.13, 'NEU': 0.7, 'POS': 0.17}
#
#
#
# 0493.txt
# NEG {'NEG': 0.94, 'NEU': 0.05, 'POS': 0.01}
#
#
#
# 0043.txt
# NEG {'NEG': 0.74, 'NEU': 0.24, 'POS': 0.02}
#
#
#
# 0062.txt
# NEU {'NEG': 0.07, 'NEU': 0.85, 'POS': 0.08}
#
#
#
# 0383.txt
# NEU {'NEG': 0.13, 'NEU': 0.67, 'POS': 0.21}
#
#
#
# 0354.txt
# NEU {'NEG': 0.09, 'NEU': 0.78, 'POS': 0.13}
#
#
#
# 0170.txt
# NEU {'NEG': 0.29, 'NEU': 0.67, 'POS': 0.03}
#
#
#
# 0472.txt
# NEU {'NEG': 0.09, 'NEU': 0.87, 'POS': 0.04}
#
#
#
# 0227.txt
# NEU {'NEG': 0.16, 'NEU': 0.81, 'POS': 0.03}
#
#
#
# 0056.txt
# NEG {'NEG': 0.73, 'NEU': 0.25, 'POS': 0.02}
#
#
#
# 0193.txt
# NEU {'NEG': 0.03, 'NEU': 0.9, 'POS': 0.07}
#
#
#
# 0119.txt
# NEU {'NEG': 0.05, 'NEU': 0.73, 'POS': 0.22}
#
#
#
# 0349.txt
# NEU {'NEG': 0.07, 'NEU': 0.88, 'POS': 0.05}
#
#
#
# 0442.txt
# NEU {'NEG': 0.42, 'NEU': 0.55, 'POS': 0.03}
#
#
#
# 0047.txt
# POS {'NEG': 0.02, 'NEU': 0.48, 'POS': 0.5}
#
#
#
# 0447.txt
# NEU {'NEG': 0.13, 'NEU': 0.79, 'POS': 0.08}
#
#
#
# 0505.txt
# NEU {'NEG': 0.09, 'NEU': 0.82, 'POS': 0.09}
#
#
#
# 0439.txt
# NEU {'NEG': 0.23, 'NEU': 0.73, 'POS': 0.04}
#
#
#
# 0104.txt
# NEU {'NEG': 0.15, 'NEU': 0.65, 'POS': 0.2}
#
#
#
# 0453.txt
# NEU {'NEG': 0.4, 'NEU': 0.56, 'POS': 0.04}
#
#
#
# 0286.txt
# NEU {'NEG': 0.21, 'NEU': 0.7, 'POS': 0.1}
#
#
#
# 0567.txt
# NEU {'NEG': 0.06, 'NEU': 0.79, 'POS': 0.15}
#
#
#
# 0360.txt
# NEU {'NEG': 0.12, 'NEU': 0.63, 'POS': 0.25}
#
#
#
# 0456.txt
# NEU {'NEG': 0.18, 'NEU': 0.74, 'POS': 0.08}
#
#
#
# 0022.txt
# NEU {'NEG': 0.06, 'NEU': 0.6, 'POS': 0.34}
#
#
#
# 0461.txt
# NEU {'NEG': 0.12, 'NEU': 0.78, 'POS': 0.09}
#
#
#
# 0316.txt
# NEG {'NEG': 0.86, 'NEU': 0.13, 'POS': 0.01}
#
#
#
# 0268.txt
# NEG {'NEG': 0.49, 'NEU': 0.46, 'POS': 0.05}
#
#
#
# 0116.txt
# NEG {'NEG': 0.82, 'NEU': 0.16, 'POS': 0.01}
#
#
#
# 0410.txt
# NEU {'NEG': 0.18, 'NEU': 0.68, 'POS': 0.14}
#
#
#
# 0337.txt
# NEU {'NEG': 0.05, 'NEU': 0.79, 'POS': 0.16}
#
#
#
# 0130.txt
# NEU {'NEG': 0.2, 'NEU': 0.74, 'POS': 0.06}
#
#
#
# 0415.txt
# NEU {'NEG': 0.08, 'NEU': 0.72, 'POS': 0.2}
#
#
#
# 0210.txt
# NEG {'NEG': 0.93, 'NEU': 0.07, 'POS': 0.0}
#
#
#
# 0195.txt
# NEU {'NEG': 0.11, 'NEU': 0.84, 'POS': 0.06}
#
#
#
# 0023.txt
# NEU {'NEG': 0.41, 'NEU': 0.56, 'POS': 0.03}
#
#
#
# 0309.txt
# NEU {'NEG': 0.14, 'NEU': 0.75, 'POS': 0.11}
#
#
#
# 0512.txt
# NEU {'NEG': 0.08, 'NEU': 0.84, 'POS': 0.08}
#
#
#
# 0382.txt
# NEU {'NEG': 0.43, 'NEU': 0.55, 'POS': 0.02}
#
#
#
# 0593.txt
# NEU {'NEG': 0.18, 'NEU': 0.74, 'POS': 0.08}
#
#
#
# 0350.txt
# NEG {'NEG': 0.58, 'NEU': 0.32, 'POS': 0.09}
#
#
#
# 0225.txt
# NEU {'NEG': 0.08, 'NEU': 0.86, 'POS': 0.06}
#
#
#
# 0211.txt
# NEU {'NEG': 0.14, 'NEU': 0.73, 'POS': 0.14}
#
#
#
# 0494.txt
# NEU {'NEG': 0.2, 'NEU': 0.75, 'POS': 0.05}
#
#
#
# 0260.txt
# NEU {'NEG': 0.15, 'NEU': 0.81, 'POS': 0.04}
#
#
#
# 0068.txt
# NEU {'NEG': 0.11, 'NEU': 0.72, 'POS': 0.16}
#
#
#
# 0371.txt
# NEU {'NEG': 0.23, 'NEU': 0.65, 'POS': 0.12}
#
#
#
# 0178.txt
# NEU {'NEG': 0.35, 'NEU': 0.63, 'POS': 0.02}
#
#
#
# 0138.txt
# NEU {'NEG': 0.07, 'NEU': 0.87, 'POS': 0.06}
#
#
#
# 0468.txt
# NEU {'NEG': 0.24, 'NEU': 0.7, 'POS': 0.06}
#
#
#
# 0390.txt
# NEU {'NEG': 0.07, 'NEU': 0.74, 'POS': 0.19}
#
#
#
# 0413.txt
# NEU {'NEG': 0.34, 'NEU': 0.62, 'POS': 0.04}
#
#
#
# 0320.txt
# NEU {'NEG': 0.17, 'NEU': 0.77, 'POS': 0.06}
#
#
#
# 0507.txt
# NEG {'NEG': 0.58, 'NEU': 0.41, 'POS': 0.02}
#
#
#
# 0452.txt
# NEU {'NEG': 0.14, 'NEU': 0.77, 'POS': 0.09}
#
#
#
# 0385.txt
# NEU {'NEG': 0.27, 'NEU': 0.63, 'POS': 0.1}
#
#
#
# 0411.txt
# NEU {'NEG': 0.15, 'NEU': 0.76, 'POS': 0.09}
#
#
#
# 0202.txt
# NEU {'NEG': 0.1, 'NEU': 0.82, 'POS': 0.08}
#
#
#
# 0233.txt
# NEU {'NEG': 0.12, 'NEU': 0.77, 'POS': 0.11}
#
#
#
# 0262.txt
# NEU {'NEG': 0.09, 'NEU': 0.85, 'POS': 0.06}
#
#
#
# 0545.txt
# NEU {'NEG': 0.08, 'NEU': 0.66, 'POS': 0.26}
#
#
#
# 0294.txt
# NEU {'NEG': 0.28, 'NEU': 0.69, 'POS': 0.03}
#
#
#
# 0376.txt
# NEU {'NEG': 0.08, 'NEU': 0.78, 'POS': 0.14}
#
#
#
# 0251.txt
# NEG {'NEG': 0.61, 'NEU': 0.37, 'POS': 0.02}
#
#
#
# 0032.txt
# NEU {'NEG': 0.08, 'NEU': 0.87, 'POS': 0.05}
#
#
#
# 0428.txt
# NEU {'NEG': 0.21, 'NEU': 0.66, 'POS': 0.14}
#
#
#
# 0112.txt
# NEU {'NEG': 0.14, 'NEU': 0.72, 'POS': 0.14}
#
#
#
# 0574.txt
# NEU {'NEG': 0.46, 'NEU': 0.47, 'POS': 0.07}
#
#
#
# 0300.txt
# NEU {'NEG': 0.3, 'NEU': 0.66, 'POS': 0.04}
#
#
#
# 0153.txt
# NEU {'NEG': 0.05, 'NEU': 0.81, 'POS': 0.14}
#
#
#
# 0060.txt
# NEU {'NEG': 0.09, 'NEU': 0.83, 'POS': 0.07}
#
#
#
# 0243.txt
# NEU {'NEG': 0.06, 'NEU': 0.78, 'POS': 0.17}
#
#
#
# 0496.txt
# NEU {'NEG': 0.12, 'NEU': 0.83, 'POS': 0.05}
#
#
#
# 0176.txt
# NEU {'NEG': 0.13, 'NEU': 0.72, 'POS': 0.15}
#
#
#
# 0182.txt
# NEG {'NEG': 0.71, 'NEU': 0.27, 'POS': 0.01}
#
#
#
# 0334.txt
# NEU {'NEG': 0.11, 'NEU': 0.75, 'POS': 0.15}
#
#
#
# 0158.txt
# NEU {'NEG': 0.38, 'NEU': 0.58, 'POS': 0.04}
#
#
#
# 0325.txt
# NEU {'NEG': 0.14, 'NEU': 0.71, 'POS': 0.15}
#
#
#
# 0479.txt
# NEU {'NEG': 0.11, 'NEU': 0.61, 'POS': 0.28}
#
#
#
# 0469.txt
# NEU {'NEG': 0.1, 'NEU': 0.85, 'POS': 0.05}
#
#
#
# 0386.txt
# NEU {'NEG': 0.1, 'NEU': 0.71, 'POS': 0.18}
#
#
#
# 0058.txt
# NEU {'NEG': 0.18, 'NEU': 0.76, 'POS': 0.06}
#
#
#
# 0554.txt
# NEU {'NEG': 0.15, 'NEU': 0.71, 'POS': 0.14}
#
#
#
# 0480.txt
# NEU {'NEG': 0.43, 'NEU': 0.48, 'POS': 0.08}
#
#
#
# 0030.txt
# NEU {'NEG': 0.24, 'NEU': 0.67, 'POS': 0.09}
#
#
#
# 0559.txt
# NEU {'NEG': 0.34, 'NEU': 0.63, 'POS': 0.03}
#
#
#
# 0450.txt
# NEU {'NEG': 0.24, 'NEU': 0.7, 'POS': 0.06}
#
#
#
# 0446.txt
# NEU {'NEG': 0.1, 'NEU': 0.83, 'POS': 0.08}
#
#
#
# 0283.txt
# NEG {'NEG': 0.74, 'NEU': 0.25, 'POS': 0.01}
#
#
#
# 0089.txt
# NEU {'NEG': 0.09, 'NEU': 0.64, 'POS': 0.26}
#
#
#
# 0113.txt
# NEU {'NEG': 0.24, 'NEU': 0.67, 'POS': 0.09}
#
#
#
# 0348.txt
# NEU {'NEG': 0.06, 'NEU': 0.81, 'POS': 0.13}
#
#
#
# 0033.txt
# NEU {'NEG': 0.36, 'NEU': 0.61, 'POS': 0.03}
#
#
#
# 0342.txt
# NEG {'NEG': 0.9, 'NEU': 0.09, 'POS': 0.01}
#
#
#
# 0474.txt
# NEU {'NEG': 0.08, 'NEU': 0.86, 'POS': 0.06}
#
#
#
# 0144.txt
# NEU {'NEG': 0.44, 'NEU': 0.51, 'POS': 0.05}
#
#
#
# 0133.txt
# NEU {'NEG': 0.16, 'NEU': 0.81, 'POS': 0.04}
#
#
#
# 0146.txt
# NEU {'NEG': 0.2, 'NEU': 0.62, 'POS': 0.19}
#
#
#
# 0422.txt
# NEU {'NEG': 0.07, 'NEU': 0.85, 'POS': 0.07}
#
#
#
# 0366.txt
# NEU {'NEG': 0.35, 'NEU': 0.57, 'POS': 0.08}
#
#
#
# 0327.txt
# NEU {'NEG': 0.07, 'NEU': 0.8, 'POS': 0.14}
#
#
#
# 0326.txt
# NEU {'NEG': 0.17, 'NEU': 0.57, 'POS': 0.26}
#
#
#
# 0596.txt
# NEG {'NEG': 0.66, 'NEU': 0.29, 'POS': 0.05}
#
#
#
# 0451.txt
# NEU {'NEG': 0.05, 'NEU': 0.81, 'POS': 0.14}
#
#
#
# 0151.txt
# NEU {'NEG': 0.15, 'NEU': 0.79, 'POS': 0.07}
#
#
#
# 0179.txt
# NEU {'NEG': 0.05, 'NEU': 0.71, 'POS': 0.24}
#
#
#
# 0008.txt
# NEU {'NEG': 0.2, 'NEU': 0.67, 'POS': 0.13}
#
#
#
# 0188.txt
# NEU {'NEG': 0.04, 'NEU': 0.64, 'POS': 0.32}
#
#
#
# 0463.txt
# NEU {'NEG': 0.14, 'NEU': 0.63, 'POS': 0.23}
#
#
#
# 0580.txt
# NEU {'NEG': 0.41, 'NEU': 0.55, 'POS': 0.04}
#
#
#
# 0328.txt
# POS {'NEG': 0.02, 'NEU': 0.43, 'POS': 0.54}
#
#
#
# 0231.txt
# NEU {'NEG': 0.1, 'NEU': 0.82, 'POS': 0.09}
#
#
#
# 0490.txt
# POS {'NEG': 0.02, 'NEU': 0.48, 'POS': 0.5}
#
#
#
# 0078.txt
# NEU {'NEG': 0.11, 'NEU': 0.76, 'POS': 0.13}
#
#
#
# 0529.txt
# NEU {'NEG': 0.09, 'NEU': 0.85, 'POS': 0.07}
#
#
#
# 0109.txt
# NEU {'NEG': 0.06, 'NEU': 0.88, 'POS': 0.05}
#
#
#
# 0273.txt
# NEG {'NEG': 0.85, 'NEU': 0.13, 'POS': 0.01}
#
#
#
# 0467.txt
# NEU {'NEG': 0.07, 'NEU': 0.85, 'POS': 0.07}
#
#
#
# 0502.txt
# NEU {'NEG': 0.43, 'NEU': 0.53, 'POS': 0.04}
#
#
#
# 0042.txt
# NEU {'NEG': 0.08, 'NEU': 0.71, 'POS': 0.22}
#
#
#
# 0287.txt
# NEU {'NEG': 0.19, 'NEU': 0.79, 'POS': 0.02}
#
#
#
# 0250.txt
# NEU {'NEG': 0.42, 'NEU': 0.52, 'POS': 0.06}
#
#
#
# 0425.txt
# NEU {'NEG': 0.06, 'NEU': 0.82, 'POS': 0.12}
#
#
#
# 0212.txt
# NEU {'NEG': 0.39, 'NEU': 0.57, 'POS': 0.04}
#
#
#
# 0353.txt
# NEG {'NEG': 0.9, 'NEU': 0.09, 'POS': 0.01}
#
#
#
# 0405.txt
# NEU {'NEG': 0.42, 'NEU': 0.54, 'POS': 0.04}
#
#
#
# 0583.txt
# NEU {'NEG': 0.24, 'NEU': 0.7, 'POS': 0.06}
#
#
#
# 0432.txt
# NEU {'NEG': 0.18, 'NEU': 0.74, 'POS': 0.08}
#
#
#
# 0240.txt
# NEU {'NEG': 0.13, 'NEU': 0.81, 'POS': 0.07}
#
#
#
# 0539.txt
# NEU {'NEG': 0.05, 'NEU': 0.84, 'POS': 0.1}
#
#
#
# 0404.txt
# NEU {'NEG': 0.08, 'NEU': 0.85, 'POS': 0.07}
#
#
#
# 0111.txt
# NEU {'NEG': 0.16, 'NEU': 0.58, 'POS': 0.26}
#
#
#
# 0548.txt
# NEU {'NEG': 0.41, 'NEU': 0.55, 'POS': 0.03}
#
#
#
# 0265.txt
# NEU {'NEG': 0.05, 'NEU': 0.66, 'POS': 0.29}
#
#
#
# 0581.txt
# NEG {'NEG': 0.51, 'NEU': 0.42, 'POS': 0.07}
#
#
#
# 0544.txt
# NEU {'NEG': 0.19, 'NEU': 0.76, 'POS': 0.05}
#
#
#
# 0338.txt
# NEU {'NEG': 0.05, 'NEU': 0.75, 'POS': 0.2}
#
#
#
# 0046.txt
# NEG {'NEG': 0.61, 'NEU': 0.37, 'POS': 0.02}
#
#
#
# 0594.txt
# NEU {'NEG': 0.16, 'NEU': 0.6, 'POS': 0.23}
#
#
#
# 0237.txt
# NEU {'NEG': 0.32, 'NEU': 0.63, 'POS': 0.05}
#
#
#
# 0103.txt
# NEG {'NEG': 0.65, 'NEU': 0.31, 'POS': 0.05}
#
#
#
# 0209.txt
# NEU {'NEG': 0.24, 'NEU': 0.49, 'POS': 0.27}
#
#
#
# 0395.txt
# NEU {'NEG': 0.04, 'NEU': 0.78, 'POS': 0.18}
#
#
#
# 0186.txt
# NEU {'NEG': 0.11, 'NEU': 0.81, 'POS': 0.08}
#
#
#
# 0417.txt
# NEU {'NEG': 0.21, 'NEU': 0.49, 'POS': 0.3}
#
#
#
# 0449.txt
# NEU {'NEG': 0.29, 'NEU': 0.68, 'POS': 0.03}
#
#
#
# 0427.txt
# NEU {'NEG': 0.43, 'NEU': 0.52, 'POS': 0.05}
#
#
#
# 0278.txt
# NEG {'NEG': 0.63, 'NEU': 0.35, 'POS': 0.02}
#
#
#
# 0021.txt
# NEU {'NEG': 0.12, 'NEU': 0.72, 'POS': 0.15}
#
#
#
# 0259.txt
# NEU {'NEG': 0.1, 'NEU': 0.86, 'POS': 0.04}
#
#
#
# 0495.txt
# NEU {'NEG': 0.15, 'NEU': 0.78, 'POS': 0.08}
#
#
#
# 0318.txt
# NEG {'NEG': 0.8, 'NEU': 0.18, 'POS': 0.02}
#
#
#
# 0194.txt
# NEU {'NEG': 0.1, 'NEU': 0.5, 'POS': 0.4}
#
#
#
# 0267.txt
# NEU {'NEG': 0.33, 'NEU': 0.58, 'POS': 0.08}
#
#
#
# 0508.txt
# NEU {'NEG': 0.34, 'NEU': 0.62, 'POS': 0.04}
#
#
#
# 0419.txt
# NEU {'NEG': 0.07, 'NEU': 0.67, 'POS': 0.26}
#
#
#
# 0102.txt
# NEU {'NEG': 0.14, 'NEU': 0.71, 'POS': 0.15}
#
#
#
# 0475.txt
# NEU {'NEG': 0.23, 'NEU': 0.71, 'POS': 0.06}
#
#
#
# 0135.txt
# NEG {'NEG': 0.59, 'NEU': 0.38, 'POS': 0.03}
#
#
#
# 0065.txt
# NEG {'NEG': 0.63, 'NEU': 0.34, 'POS': 0.03}
#
#
#
# 0254.txt
# NEU {'NEG': 0.14, 'NEU': 0.7, 'POS': 0.16}
#
#
#
# 0054.txt
# NEG {'NEG': 0.9, 'NEU': 0.09, 'POS': 0.01}
#
#
#
# 0230.txt
# NEU {'NEG': 0.15, 'NEU': 0.76, 'POS': 0.08}
#
#
#
# 0524.txt
# NEU {'NEG': 0.06, 'NEU': 0.89, 'POS': 0.06}
#
#
#
# 0313.txt
# NEU {'NEG': 0.24, 'NEU': 0.65, 'POS': 0.11}
#
#
#
# 0077.txt
# NEU {'NEG': 0.36, 'NEU': 0.61, 'POS': 0.03}
#
#
#
# 0244.txt
# NEU {'NEG': 0.12, 'NEU': 0.81, 'POS': 0.06}
#
#
#
# 0367.txt
# NEU {'NEG': 0.08, 'NEU': 0.63, 'POS': 0.29}
#
#
#
# 0285.txt
# NEG {'NEG': 0.81, 'NEU': 0.18, 'POS': 0.01}
#
#
#
# 0315.txt
# NEU {'NEG': 0.35, 'NEU': 0.5, 'POS': 0.15}
#
#
#
# 0272.txt
# NEU {'NEG': 0.12, 'NEU': 0.83, 'POS': 0.05}
#
#
#
# 0492.txt
# NEG {'NEG': 0.74, 'NEU': 0.23, 'POS': 0.03}
#
#
#
# 0050.txt
# NEU {'NEG': 0.37, 'NEU': 0.57, 'POS': 0.06}
#
#
#
# 0443.txt
# NEU {'NEG': 0.08, 'NEU': 0.7, 'POS': 0.22}
#
#
#
# 0403.txt
# NEU {'NEG': 0.13, 'NEU': 0.6, 'POS': 0.27}
#
#
#
# 0122.txt
# NEU {'NEG': 0.15, 'NEU': 0.73, 'POS': 0.12}
#
#
#
# 0039.txt
# NEU {'NEG': 0.24, 'NEU': 0.73, 'POS': 0.03}
#
#
#
# 0482.txt
# NEU {'NEG': 0.17, 'NEU': 0.76, 'POS': 0.07}
#
#
#
# 0370.txt
# NEU {'NEG': 0.24, 'NEU': 0.7, 'POS': 0.06}
#
#
#
# 0253.txt
# NEU {'NEG': 0.14, 'NEU': 0.81, 'POS': 0.05}
#
#
#
# 0108.txt
# NEU {'NEG': 0.1, 'NEU': 0.78, 'POS': 0.12}
#
#
#
# 0566.txt
# NEU {'NEG': 0.08, 'NEU': 0.8, 'POS': 0.12}
#
#
#
# 0129.txt
# NEU {'NEG': 0.18, 'NEU': 0.74, 'POS': 0.08}
#
#
#
# 0088.txt
# NEG {'NEG': 0.93, 'NEU': 0.06, 'POS': 0.01}
#
#
#
# 0532.txt
# NEU {'NEG': 0.09, 'NEU': 0.84, 'POS': 0.08}
#
#
#
# 0399.txt
# NEU {'NEG': 0.27, 'NEU': 0.65, 'POS': 0.08}
#
#
#
# 0407.txt
# NEU {'NEG': 0.37, 'NEU': 0.53, 'POS': 0.1}
#
#
#
# 0257.txt
# NEU {'NEG': 0.09, 'NEU': 0.82, 'POS': 0.09}
#
#
#
# 0573.txt
# NEU {'NEG': 0.22, 'NEU': 0.69, 'POS': 0.09}
#
#
#
# 0565.txt
# NEU {'NEG': 0.14, 'NEU': 0.77, 'POS': 0.09}
#
#
#
# 0308.txt
# NEU {'NEG': 0.08, 'NEU': 0.81, 'POS': 0.11}
#
#
#
# 0031.txt
# NEU {'NEG': 0.23, 'NEU': 0.73, 'POS': 0.04}
#
#
#
# 0584.txt
# NEU {'NEG': 0.04, 'NEU': 0.56, 'POS': 0.4}
#
#
#
# 0588.txt
# NEU {'NEG': 0.21, 'NEU': 0.75, 'POS': 0.04}
#
#
#
# 0035.txt
# NEU {'NEG': 0.09, 'NEU': 0.8, 'POS': 0.1}
#
#
#
# 0290.txt
# NEU {'NEG': 0.06, 'NEU': 0.79, 'POS': 0.15}
#
#
#
# 0306.txt
# POS {'NEG': 0.01, 'NEU': 0.32, 'POS': 0.67}
#
#
#
# 0149.txt
# NEG {'NEG': 0.81, 'NEU': 0.18, 'POS': 0.01}
#
#
#
# 0517.txt
# NEU {'NEG': 0.44, 'NEU': 0.52, 'POS': 0.04}
#
#
#
# 0455.txt
# NEU {'NEG': 0.12, 'NEU': 0.82, 'POS': 0.07}
#
#
#
# 0576.txt
# NEU {'NEG': 0.08, 'NEU': 0.82, 'POS': 0.1}
#
#
#
# 0563.txt
# NEU {'NEG': 0.05, 'NEU': 0.81, 'POS': 0.15}
#
#
#
# 0378.txt
# NEU {'NEG': 0.12, 'NEU': 0.66, 'POS': 0.22}
#
#
#
# 0520.txt
# NEG {'NEG': 0.57, 'NEU': 0.39, 'POS': 0.03}
#
#
#
# 0090.txt
# NEU {'NEG': 0.37, 'NEU': 0.58, 'POS': 0.05}
#
#
#
# 0041.txt
# NEU {'NEG': 0.18, 'NEU': 0.74, 'POS': 0.09}
#
#
#
# 0073.txt
# NEU {'NEG': 0.2, 'NEU': 0.69, 'POS': 0.11}
#
#
#
# 0018.txt
# NEU {'NEG': 0.1, 'NEU': 0.64, 'POS': 0.26}
#
#
#
# 0292.txt
# NEU {'NEG': 0.1, 'NEU': 0.73, 'POS': 0.17}
#
#
#
# 0061.txt
# NEG {'NEG': 0.48, 'NEU': 0.46, 'POS': 0.05}
#
#
#
# 0341.txt
# NEU {'NEG': 0.19, 'NEU': 0.71, 'POS': 0.09}
#
#
#
# 0358.txt
# NEU {'NEG': 0.24, 'NEU': 0.7, 'POS': 0.06}
#
#
#
# 0006.txt
# NEU {'NEG': 0.09, 'NEU': 0.87, 'POS': 0.04}
#
#
#
# 0224.txt
# NEU {'NEG': 0.1, 'NEU': 0.78, 'POS': 0.12}
#
#
#
# 0519.txt
# NEU {'NEG': 0.24, 'NEU': 0.69, 'POS': 0.07}
#
#
#
# 0098.txt
# NEU {'NEG': 0.08, 'NEU': 0.87, 'POS': 0.05}
#
#
#
# 0323.txt
# NEU {'NEG': 0.15, 'NEU': 0.8, 'POS': 0.04}
#
#
#
# 0464.txt
# NEU {'NEG': 0.19, 'NEU': 0.74, 'POS': 0.07}
#
#
#
# 0477.txt
# NEU {'NEG': 0.08, 'NEU': 0.88, 'POS': 0.04}
#
#
#
# 0553.txt
# NEG {'NEG': 0.51, 'NEU': 0.46, 'POS': 0.04}
#
#
#
# 0486.txt
# NEU {'NEG': 0.08, 'NEU': 0.84, 'POS': 0.08}
#
#
#
# 0036.txt
# NEU {'NEG': 0.06, 'NEU': 0.62, 'POS': 0.32}
#
#
#
# 0081.txt
# NEU {'NEG': 0.06, 'NEU': 0.88, 'POS': 0.06}
#
#
#
# 0147.txt
# NEU {'NEG': 0.06, 'NEU': 0.59, 'POS': 0.36}
#
#
#
# 0540.txt
# NEU {'NEG': 0.18, 'NEU': 0.78, 'POS': 0.04}
#
#
#
# 0000.txt
# NEU {'NEG': 0.07, 'NEU': 0.87, 'POS': 0.07}
#
#
#
# 0460.txt
# NEU {'NEG': 0.1, 'NEU': 0.67, 'POS': 0.23}
#
#
#
# 0503.txt
# NEU {'NEG': 0.24, 'NEU': 0.71, 'POS': 0.04}
#
#
#
# 0236.txt
# NEU {'NEG': 0.19, 'NEU': 0.75, 'POS': 0.06}
#
#
#
# 0124.txt
# NEU {'NEG': 0.05, 'NEU': 0.76, 'POS': 0.19}
#
#
#
# 0134.txt
# NEU {'NEG': 0.17, 'NEU': 0.72, 'POS': 0.12}
#
#
#
# 0542.txt
# NEU {'NEG': 0.07, 'NEU': 0.86, 'POS': 0.07}
#
#
#
# 0118.txt
# NEG {'NEG': 0.55, 'NEU': 0.43, 'POS': 0.02}
#
#
#
# 0440.txt
# NEU {'NEG': 0.29, 'NEU': 0.67, 'POS': 0.04}
#
#
#
# 0197.txt
# NEU {'NEG': 0.13, 'NEU': 0.75, 'POS': 0.12}
#
#
#
# 0069.txt
# NEU {'NEG': 0.18, 'NEU': 0.75, 'POS': 0.06}
#
#
#
# 0241.txt
# NEU {'NEG': 0.1, 'NEU': 0.86, 'POS': 0.04}
#
#
#
# 0037.txt
# NEU {'NEG': 0.08, 'NEU': 0.76, 'POS': 0.15}
#
#
#
# 0595.txt
# NEG {'NEG': 0.61, 'NEU': 0.35, 'POS': 0.04}
#
#
#
# 0015.txt
# NEU {'NEG': 0.16, 'NEU': 0.67, 'POS': 0.17}
#
#
#
# 0433.txt
# NEU {'NEG': 0.32, 'NEU': 0.59, 'POS': 0.09}
#
#
#
# 0096.txt
# NEU {'NEG': 0.2, 'NEU': 0.76, 'POS': 0.04}
#
#
#
# 0336.txt
# NEG {'NEG': 0.64, 'NEU': 0.34, 'POS': 0.02}
#
#
#
# 0295.txt
# NEU {'NEG': 0.05, 'NEU': 0.74, 'POS': 0.21}
#
#
#
# 0361.txt
# NEU {'NEG': 0.18, 'NEU': 0.73, 'POS': 0.09}
#
#
#
# 0184.txt
# NEU {'NEG': 0.09, 'NEU': 0.77, 'POS': 0.13}
#
#
#
# 0436.txt
# NEU {'NEG': 0.1, 'NEU': 0.81, 'POS': 0.09}
#
#
#
# 0072.txt
# NEU {'NEG': 0.06, 'NEU': 0.79, 'POS': 0.15}
#
#
#
# 0314.txt
# NEU {'NEG': 0.03, 'NEU': 0.63, 'POS': 0.34}
#
#
#
# 0518.txt
# NEU {'NEG': 0.03, 'NEU': 0.69, 'POS': 0.28}
#
#
#
# 0208.txt
# NEU {'NEG': 0.08, 'NEU': 0.84, 'POS': 0.08}
#
#
#
# 0321.txt
# NEU {'NEG': 0.15, 'NEU': 0.74, 'POS': 0.11}
#
#
#
# 0028.txt
# NEU {'NEG': 0.18, 'NEU': 0.65, 'POS': 0.17}
#
#
#
# 0585.txt
# NEU {'NEG': 0.07, 'NEU': 0.72, 'POS': 0.21}
#
#
#
# 0307.txt
# NEU {'NEG': 0.34, 'NEU': 0.63, 'POS': 0.03}
#
#
#
# 0424.txt
# NEU {'NEG': 0.19, 'NEU': 0.69, 'POS': 0.11}
#
#
#
# 0500.txt
# NEU {'NEG': 0.29, 'NEU': 0.59, 'POS': 0.12}
#
#
#
# 0213.txt
# NEU {'NEG': 0.12, 'NEU': 0.76, 'POS': 0.13}
#
#
#
# 0322.txt
# NEG {'NEG': 0.83, 'NEU': 0.16, 'POS': 0.01}
#
#
#
# 0252.txt
# NEU {'NEG': 0.08, 'NEU': 0.79, 'POS': 0.14}
#
#
#
# 0070.txt
# NEU {'NEG': 0.03, 'NEU': 0.74, 'POS': 0.24}
#
#
#
# 0457.txt
# NEU {'NEG': 0.24, 'NEU': 0.67, 'POS': 0.09}
#
#
#
# 0375.txt
# NEU {'NEG': 0.04, 'NEU': 0.66, 'POS': 0.3}
#
#
#
# 0142.txt
# NEU {'NEG': 0.14, 'NEU': 0.69, 'POS': 0.16}
#
#
#
# 0189.txt
# NEU {'NEG': 0.05, 'NEU': 0.66, 'POS': 0.29}
#
#
#
# 0570.txt
# NEU {'NEG': 0.21, 'NEU': 0.73, 'POS': 0.05}
#
#
#
# 0543.txt
# NEU {'NEG': 0.03, 'NEU': 0.78, 'POS': 0.19}
#
#
#
# 0509.txt
# NEG {'NEG': 0.91, 'NEU': 0.09, 'POS': 0.01}
#
#
#
# 0003.txt
# NEG {'NEG': 0.52, 'NEU': 0.44, 'POS': 0.03}
#
#
#
# 0414.txt
# NEU {'NEG': 0.09, 'NEU': 0.79, 'POS': 0.12}
#
#
#
# 0560.txt
# NEU {'NEG': 0.1, 'NEU': 0.77, 'POS': 0.13}
#
#
#
# 0363.txt
# NEU {'NEG': 0.19, 'NEU': 0.74, 'POS': 0.07}
#
#
#
# 0288.txt
# NEU {'NEG': 0.13, 'NEU': 0.79, 'POS': 0.07}
#
#
#
# 0311.txt
# NEU {'NEG': 0.05, 'NEU': 0.83, 'POS': 0.12}
#
#
#
# 0346.txt
# NEG {'NEG': 0.81, 'NEU': 0.18, 'POS': 0.01}
#
#
#
# 0514.txt
# NEU {'NEG': 0.32, 'NEU': 0.6, 'POS': 0.09}
#
#
#
# 0001.txt
# NEU {'NEG': 0.09, 'NEU': 0.83, 'POS': 0.07}
#
#
#
# 0421.txt
# NEU {'NEG': 0.12, 'NEU': 0.81, 'POS': 0.07}
#
#
#
# 0010.txt
# POS {'NEG': 0.21, 'NEU': 0.29, 'POS': 0.5}
#
#
#
# 0521.txt
# NEG {'NEG': 0.73, 'NEU': 0.25, 'POS': 0.02}
#
#
#
# 0364.txt
# NEU {'NEG': 0.04, 'NEU': 0.69, 'POS': 0.28}
#
#
#
# 0066.txt
# NEU {'NEG': 0.4, 'NEU': 0.55, 'POS': 0.05}
#
#
#
# 0437.txt
# NEU {'NEG': 0.13, 'NEU': 0.8, 'POS': 0.06}
#
#
#
# 0161.txt
# NEU {'NEG': 0.22, 'NEU': 0.67, 'POS': 0.11}
#
#
#
# 0071.txt
# NEU {'NEG': 0.19, 'NEU': 0.74, 'POS': 0.07}
#
#
#
# 0296.txt
# NEU {'NEG': 0.28, 'NEU': 0.53, 'POS': 0.18}
#
#
#
# 0491.txt
# NEU {'NEG': 0.17, 'NEU': 0.58, 'POS': 0.26}
#
#
#
# 0418.txt
# NEU {'NEG': 0.09, 'NEU': 0.67, 'POS': 0.24}
#
#
#
# 0175.txt
# NEU {'NEG': 0.22, 'NEU': 0.51, 'POS': 0.27}
#
#
#
# 0027.txt
# NEU {'NEG': 0.33, 'NEU': 0.64, 'POS': 0.03}
#
#
#
# 0136.txt
# NEU {'NEG': 0.44, 'NEU': 0.53, 'POS': 0.03}
#
#
#
# 0355.txt
# NEU {'NEG': 0.19, 'NEU': 0.76, 'POS': 0.05}
#
#
#
# 0100.txt
# NEG {'NEG': 0.92, 'NEU': 0.08, 'POS': 0.01}
#
#
#
# 0177.txt
# NEU {'NEG': 0.06, 'NEU': 0.83, 'POS': 0.11}
#
#
#
# 0392.txt
# NEU {'NEG': 0.05, 'NEU': 0.85, 'POS': 0.1}
#
#
#
# 0528.txt
# POS {'NEG': 0.02, 'NEU': 0.45, 'POS': 0.52}
#
#
#
# 0426.txt
# NEU {'NEG': 0.25, 'NEU': 0.68, 'POS': 0.07}
#
#
#
# 0095.txt
# NEU {'NEG': 0.28, 'NEU': 0.61, 'POS': 0.11}
#
#
#
# 0347.txt
# NEU {'NEG': 0.21, 'NEU': 0.76, 'POS': 0.03}
#
#
#
# 0173.txt
# NEG {'NEG': 0.66, 'NEU': 0.3, 'POS': 0.05}
#
#
#
# 0501.txt
# NEU {'NEG': 0.1, 'NEU': 0.76, 'POS': 0.14}
#
#
#
# 0009.txt
# NEU {'NEG': 0.19, 'NEU': 0.68, 'POS': 0.14}
#
#
#
# 0575.txt
# NEU {'NEG': 0.32, 'NEU': 0.65, 'POS': 0.03}
#
#
#
# 0373.txt
# NEG {'NEG': 0.64, 'NEU': 0.32, 'POS': 0.04}
#
#
#
# 0462.txt
# NEU {'NEG': 0.11, 'NEU': 0.74, 'POS': 0.15}

# %%
df = pd.DataFrame.from_dict(results, orient='index')
df.index = df.index.astype(int)
df.loc[1] = 0
df.loc[10] = 0
df = df.sort_index()
df = df*100
df
# Out:
#       NEG   NEU   POS
# 0     7.0  87.0   7.0
# 1     0.0   0.0   0.0
# 2    33.0  64.0   3.0
# 3    52.0  44.0   3.0
# 4    25.0  68.0   8.0
# ..    ...   ...   ...
# 592  76.0  21.0   3.0
# 593  18.0  74.0   8.0
# 594  16.0  60.0  23.0
# 595  61.0  35.0   4.0
# 596  66.0  29.0   5.0
#
# [551 rows x 3 columns]

# %%
threshold = 60
sentiments_mean = df.mean(axis=0)

plt.figure(figsize=(10, 4))
sentiments_mean.plot(kind="bar")
plt.title("Promedio de porcentaje por sentimiento")
plt.xlabel("Sentimientos")
plt.ylabel("Promedio (%)")
plt.xticks(rotation=45, ha='right')
plt.ylim(0, 100)
plt.tight_layout()
plt.show()

# --- 2) Porcentaje de celdas que superan el threshold por emoción ---
rate_above_threshold = (df >= threshold).sum(axis=0)/df.shape[0] * 100

plt.figure(figsize=(10, 4))
rate_above_threshold.plot(kind="bar")
plt.title(f"Porcentaje de textos con porcentaje ≥ {threshold}% por emoción")
plt.xlabel("Emociones")
plt.ylabel("Porcentaje (%)")
plt.xticks(rotation=45, ha='right')
plt.ylim(0, 100)
plt.tight_layout()
plt.show()

# %%
path_forms = "./anotaciones_corrupcion_modificado.csv"
df_forms = pd.read_csv(path_forms, header=0)

incisos_emociones = {"a)": "Alegría",
                    "b)": "Tristeza",
                    "c)": "Ira",
                    "d)": "Miedo",
                    "e)": "Sorpresa",
                    "f)": "Vergüenza",
                    "g)": "Culpa",
                    "h)": "Ninguna"
                    }

def extraer_incisos(cadena: str, unico=False):
    """
    Devuelve solo los incisos (a), b), ...) extraídos de la cadena.
    - unico=True: devuelve solo el primer inciso encontrado (o "")
    - unico=False: devuelve todos los incisos separados por espacio
    """
    if not isinstance(cadena, str):
        return ""
    # Busca incisos válidos (ajusta rango [a-i] según tu caso)
    encontrados = re.findall(r'([a-i]\))', cadena.lower())
    if unico:
        return encontrados[0] if encontrados else ""
    else:
        # quitar duplicados preservando orden
        vistos = set()
        unicos = [x for x in encontrados if not (x in vistos or vistos.add(x))]
        return " ".join(unicos)

df_forms.drop(columns=["Marca temporal", "Nombre", "Correo electrónico", "Tiempo aproximado (en minutos) que te tomo revisar el sitio web/texto y contestar todas las preguntas para este sitio web/texto específico:", "Algún comentario adicional que crees que es relevante indicar sobre la página web considerando las preguntas y la temática de corrupción (opcional):\n", "Algún comentario que quieras compartir sobre el cuestionario y la tarea de anotación que estás llevando a cabo (opcional):\n"], inplace=True)
df_forms.rename(columns={"Selecciona una de las 10 páginas a etiquetar": "pagina",
                    "1. Identifica el tipo de entidad que ha publicado el sitio web/texto:": "tipo_entidad",
                    "2. Origen de la entidad que publica el sitio web:": "origen_entidad",
                    '3. Identifica el principal propósito que tiene el contenido del sitio web:': "proposito",
                    '4. El  sitio web/texto principalmente presenta información de forma:': "informacion_presentada",
                    '5. Presenta una visión de la corrupción centrada en:': "vision",
                    '6. Respecto a las consecuencias de la corrupción el  sitio web/texto hace referencia a:': "consecuencias",
                    '7. El  sitio web/texto centra la atención en mostrar:': "que_muestra",
                    '8. Determine cuál es la intención del llamado general hacia el lector:': "intencion",
                    '9. Se presenta la corrupción como como un problema:': "localizacion_problema",
                    '10. Entes involucrados o descritos en el sitio web/texto son:': "involucrados",
                    '11. Respecto al estilo del sitio web/texto, seleccione el nivel de formalidad en el lenguaje:': "formalidad",
                    '12. Estime el nivel de educación necesario para comprender todo el sitio web/texto (o al que parece que se dirigirá el sitio web/texto):': "nivel_educacion",
                    '13. El tono general del sitio web/texto es:': "tono",
                    '14. Apela a alguna de las siguientes emociones:': "emociones"
                    }, inplace=True)

paginas = df_forms["pagina"].unique()
paginas_dict = {i: page[2:] for i, page in enumerate(paginas)}
paginas_dict[9] = paginas_dict[9][1:]

preguntas = df_forms.columns[1:]
multi_answer = ["proposito", "informacion_presentada", "consecuencias", "intencion", "localizacion_problema", "involucrados", "emociones"]

for p in preguntas:
    df_forms[p] = df_forms[p].apply(extraer_incisos, unico=(p not in multi_answer))

num = df_forms['pagina'].astype(str).str.extract(r'^\s*(\d+)')  # captura dígitos al inicio
df_forms['pagina'] = num.fillna(df_forms['pagina']).astype(str)
df_forms['pagina'] = pd.to_numeric(df_forms['pagina'], errors='coerce').astype('Int64')

def calcular_porcentajes(df, pregunta, orden_paginas, posibles_list=None):
    """Devuelve tabla porcentual (páginas × respuestas/incisos)."""
    if posibles_list is None:
        # respuesta única
        tabla = (df.groupby(["pagina", pregunta]).size().unstack(fill_value=0))
        tabla = tabla.reindex(orden_paginas, fill_value=0)
        return tabla.div(tabla.sum(axis=1).replace(0,1), axis=0) * 100
    else:
        # multi-respuesta (incisos separados por espacios)
        posibles_set = set(posibles_list)
        tmp = df[["pagina", pregunta]].copy()
        tmp[pregunta] = tmp[pregunta].fillna("").astype(str).str.strip().str.lower()
        tmp["inciso"] = tmp[pregunta].apply(
            lambda s: list(dict.fromkeys(t for t in s.split() if t in posibles_set))
        )
        den = tmp.groupby("pagina").size().reindex(orden_paginas, fill_value=0)
        expd = tmp.explode("inciso", ignore_index=True)
        expd = expd[expd["inciso"].notna() & (expd["inciso"] != "")]
        counts = expd.groupby(["pagina", "inciso"]).size().unstack(fill_value=0)
        counts = counts.reindex(orden_paginas, columns=posibles_list, fill_value=0)
        return counts.div(den.replace(0,1), axis=0) * 100
    
def conjuntos_activos(porcentajes: pd.DataFrame, umbral: float) -> dict:
    """
    Devuelve {pagina: set(incisos)} con incisos activos por página (>= umbral %).
    porcentajes: DataFrame (index=paginas, columns=incisos) con %.
    """
    activos = {}
    for pag, fila in porcentajes.iterrows():
        incisos = set(fila.index[fila.values >= umbral])
        activos[pag] = incisos
    return activos

def jaccard(act_forms: dict, act_llama: dict, paginas: list) -> pd.Series:
    vals = []
    idx  = []
    for pag in paginas:
        A = act_forms.get(pag, set())
        B = act_llama.get(pag, set())
        union = len(A | B)
        inter = len(A & B)
        score = inter / union if union > 0 else 1.0  # si ambos vacíos, los consideramos iguales (=1)
        vals.append(score); idx.append(pag)
    return pd.Series(vals, index=idx, name="jaccard")

# %%
porcentaje_concenso = 60

orden = {}
orden_paginas = list(range(1, 11))

posibles_list = ['a)', 'b)', 'c)', 'd)', 'e)', 'f)', 'g)', 'h)']

#out = Path("./graficas")
#out.mkdir(exist_ok=True)

# Paleta de colores global
inc = ["a)", "b)", "c)", "d)", "e)", "f)", "g)", "h)", "i)"]
colores = plt.cm.tab10.colors  # o 'tab20', 'Set3', etc.
color_map = {c: colores[i % len(colores)] for i, c in enumerate(inc)}

accuracies = []
jaccards = []

porcentajes_emociones = calcular_porcentajes(df_forms, "emociones", orden_paginas, posibles_list)

from matplotlib import gridspec
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(14, 6))

# 3 columnas: [heatmap_1][heatmap_2][colorbar]
gs = gridspec.GridSpec(
    1, 3,
    width_ratios=[1, 1, 0.05],  # la última columna es solo para la barra
    wspace=0.2
)

ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[0, 1])
cax = fig.add_subplot(gs[0, 2])  # barra de color vertical

# === Heatmap de anotadores ===
im1 = ax1.imshow(porcentajes_emociones.values, aspect='auto', vmin=0, vmax=100, cmap="viridis")
emociones_labels = [incisos_emociones.get(inc, inc) for inc in porcentajes_emociones.columns]
ax1.set_xticks(range(len(porcentajes_emociones.columns)))
ax1.set_xticklabels(emociones_labels, rotation=45, ha='right')
ax1.set_yticks(range(len(porcentajes_emociones.index)))
ax1.set_yticklabels(porcentajes_emociones.index)
ax1.set_title("Anotadores")
ax1.set_xlabel("Emociones")
ax1.set_ylabel("Página")

# === Marcar celdas con valor ≥ porcentaje_concenso ===
mask = porcentajes_emociones.values >= porcentaje_concenso
ys, xs = np.where(mask)
ax1.scatter(xs, ys, s=60, c='w', marker='x', linewidths=2)

# === Heatmap de modelo (por ejemplo, RoBERTuito) ===
im2 = ax2.imshow(df.values, aspect='auto', vmin=0, vmax=100, cmap="viridis")
ax2.set_xticks(range(len(df.columns)))
ax2.set_xticklabels(df.columns, rotation=45, ha='right')
ax2.set_yticks(range(len(df.index)))
ax2.set_yticklabels(df.index)
ax2.set_title("RoBERTuito")
ax2.set_xlabel("Emociones")
ax2.set_ylabel("")

mask = df.values >= porcentaje_concenso
ys, xs = np.where(mask)
ax2.scatter(xs, ys, s=60, c='w', marker='x', linewidths=2)

# === Barra de color vertical (compartida) ===
cb = fig.colorbar(im1, cax=cax, orientation="vertical")
cb.set_label("% de respuestas")

fig.suptitle("Comparación de 'emociones' entre datasets", fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()
# Out:
# /tmp/ipykernel_11115/280151244.py:72: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 1, 0.96])
